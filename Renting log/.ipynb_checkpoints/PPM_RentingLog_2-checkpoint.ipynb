# %% [markdown]
# ## Renting Event Logs

# %% [markdown]
# - <b>Processo</b>: Os dados encapsulam um processo detalhado de aluguel, desde um pedido de visualização de uma propriedade até uma possível rescisão do contrato. As etapas intermediárias incluem triagem inicial, visualização da propriedade, tomada de decisão e, possivelmente, uma triagem completa. Se aprovado, um contrato de aluguel tem início, onde os atrasos nos pagamentos podem levar ao despejo, um potencial ponto final do processo. Alternativamente, os inquilinos podem rescindir voluntariamente os seus contratos. Observe que nem todos os aplicativos passam para a fase de visualização.
#
# - <b>Atributos</b>: os logs contêm atributos que podem esclarecer possíveis distorções no processo. ‘Idade’, ‘cidadão’, ‘língua alemã’, ‘género’, ‘afiliação religiosa’ e ‘anos de educação’ podem influenciar o processo de aluguel, levando a uma potencial discriminação. Embora alguns atributos possam fornecer informações úteis sobre a fiabilidade de um potencial inquilino, a utilização indevida pode resultar em discriminação. Assim, a justiça deve ser observada na utilização destes atributos para evitar potenciais preconceitos e garantir um tratamento equitativo.
#
# - <b>Três registros de eventos</b>: os três registos de eventos representam vários graus de discriminação, oferecendo aos investigadores uma oportunidade de explorar as nuances e complexidades que surgem em diversos cenários do mundo real.

# %% [markdown]
# | Base | Eventos | Cases | Variantes | Atividades |
# | --- | --- | --- | --- | --- |
# | hiring_log_high | 89972 | 10000 | 496 | 16 |
# | hiring_log_low | 96440 | 10000 | 508 | 16 |
# | hiring_log_medim | 105555 | 10000 | 610 | 16|

# %% [markdown]
# - <b>Atributos sensíveis</b>:
#     - Age
#     - Citizenship
#     - German Proficiency
#     - Gender
#     - Years of Education
#     - Married

# %% [markdown]
# ### Importar bibliotecas

# %%
import pandas as pd
import numpy as np
import random
import os
import sys

import pm4py

import tensorflow.compat.v1 as tf

#Biblioteca implementada com funções customizadas
# Adicionar o caminho da pasta onde está a biblioteca ao sys.path
sys.path.append(os.path.abspath('C:\\Users\\micka\\OneDrive\\Documentos\\[EACH USP] Doutorado\\2. Pesquisa\\6. Experimento\\3. Predictive Process Monitoring'))
from _PythonProcessMining import TraceEncoding
from _PythonProcessMining import ResourceEncoding
from _PythonProcessMining import DataPrep
from _PythonProcessMining import TrainTestSplit
from _PythonProcessMining import MachineLearning
from _PythonProcessMining import Metrics
from _PythonProcessMining import MachineLearninExplanation
from _PythonProcessMining import AIF360

# Definir seeds para reprodutibilidade
tf.set_random_seed(42)
np.random.seed(42)
random.seed(42)
# Out:
# C:\Users\micka\anaconda3\Lib\site-packages\torch\_functorch\deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# WARNING:tensorflow:From C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\AIF360.py:339: The name tf.disable_v2_behavior is deprecated. Please use tf.compat.v1.disable_v2_behavior instead.
#
# WARNING:tensorflow:From C:\Users\micka\anaconda3\Lib\site-packages\tensorflow\python\compat\v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\micka\AppData\Local\Temp\ipykernel_14256\618957644.py:24: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %% [markdown]
# ### Importar a base de dados

# %%
diretorio_log = "C:\\Users\\micka\\OneDrive\\Documentos\\[EACH USP] Doutorado\\2. Pesquisa\\6. Experimento\\0. Logs\\Renting log\\"
diretorio = ".\\Renting log\\Renting\\"
name_prefix = 'renting_log'

# %%
log_high = pm4py.read_xes(os.path.join(diretorio_log, f'{name_prefix}_high-xes.gz'))
log_medium = pm4py.read_xes(os.path.join(diretorio_log, f'{name_prefix}_medium-xes.gz'))
log_low = pm4py.read_xes(os.path.join(diretorio_log, f'{name_prefix}_low-xes.gz'))

print("Tamanho da base de dados - High:", log_high.shape)
print("Tamanho da base de dados - Medium:", log_medium.shape)
print("Tamanho da base de dados - Low:", log_low.shape)
# Out:
# parsing log, completed traces ::   0%|          | 0/10000 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/10000 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/10000 [00:00<?, ?it/s]
# Tamanho da base de dados - High: (89972, 16)
# Tamanho da base de dados - Medium: (105555, 16)
# Tamanho da base de dados - Low: (96440, 16)

# %%
log_high.to_csv(f'{name_prefix}_high-csv.csv')
log_medium.to_csv(f'{name_prefix}_medium-csv.csv')
log_low.to_csv(f'{name_prefix}_low-csv.csv')

# %% [markdown]
# ### Preparação da base

# %% [markdown]
# <b>Definição do processo</b>

# %% [markdown]
# We want to evaluate the process up until the decision on approval of the rental agreement, which is concluded with two activities:
# - Rejected Prospective Tenant (negative);
# - Sign Contract (positive).

# %%
def def_FilterProcess(df, case_col, timestamp_col, activity_col, activities_of_interest):
    # Filtrar para encontrar a primeira ocorrência das atividades de interesse
    df_interest = df[df[activity_col].isin(activities_of_interest)]
    cutoff_times = df_interest.groupby(case_col)[timestamp_col].min()

    # Definir função para filtrar os registros
    def filter_records(row):
        if row[case_col] in cutoff_times:
            return row[timestamp_col] <= cutoff_times[row[case_col]]
        return True  # Mantém registros de casos sem as atividades de interesse

    # Aplicar o filtro
    filtered_df = df[df.apply(filter_records, axis=1)]

    return filtered_df

# %%
activities = ['Sign Contract', 'Reject Prospective Tenant']
log_high = def_FilterProcess(log_high, 'case:concept:name', 'time:timestamp', 'activity', activities)
log_medium = def_FilterProcess(log_medium, 'case:concept:name', 'time:timestamp', 'activity', activities)
log_low = def_FilterProcess(log_low, 'case:concept:name', 'time:timestamp', 'activity', activities)

# %%
print("Tamanho da base de dados - High:", log_high.shape)
print("Tamanho da base de dados - Medium:", log_medium.shape)
print("Tamanho da base de dados - Low:", log_low.shape)
# Out:
# Tamanho da base de dados - High: (63418, 16)
# Tamanho da base de dados - Medium: (66785, 16)
# Tamanho da base de dados - Low: (65546, 16)

# %% [markdown]
# <b>Resultado do case</b>

# %% [markdown]
# Adicionamos uma coluna de "Resultado" à base de dados:
# - Última atividade realizada no case;
# - Definir se o resultado é positivo ou negativo.

# %%
def def_determine_result(df):
    # Ordena o DataFrame por ID do caso e timestamp para garantir a ordem dos eventos
    df = df.sort_values(by=['case:concept:name', 'time:timestamp'])

    # Identifica o último evento de cada caso
    last_events = df.groupby('case:concept:name').last().reset_index()

    # Função interna para determinar o resultado baseado no último evento
    def df_aux_determine_result(event):
        if event == 'Sign Contract':
            return 'Positive'
        elif event == 'Reject Prospective Tenant':
            return 'Negative'
        else:
            return 'Undefined'  # para casos que não terminam com um desses eventos

    # Aplica a função para determinar o resultado de cada caso
    last_events['Resultado'] = last_events['concept:name'].apply(df_aux_determine_result)

    # Merge o resultado de volta ao DataFrame original
    df = df.merge(last_events[['case:concept:name', 'Resultado']], on='case:concept:name', how='left')
    
    return df

# %%
df_log_high = def_determine_result(log_high)
df_log_medium = def_determine_result(log_medium)
df_log_low = def_determine_result(log_low)

# %%
def def_descriptive_results(df):
    # Parte 1: Eliminar duplicidade de caso
    df_unico = df.drop_duplicates(subset='case:concept:name', keep='first')
    
    # Parte 2: Calcular o % de registros com 'Resultado' igual a 1
    total_registros = len(df_unico)  # Total de registros após eliminar duplicidades
    registros_resultado = len(df_unico[df_unico['Resultado'] == 'Positive'])  # Registros com Resultado == 1
    percentual_resultado = (registros_resultado / total_registros) * 100  # Cálculo do percentual
    
    return percentual_resultado

# %%
print("Percentual de registros com 'Resultado' positivo - High: {:.2f}%".format(def_descriptive_results(df_log_high)))
print("Percentual de registros com 'Resultado' positivo - Medium: {:.2f}%".format(def_descriptive_results(df_log_medium)))
print("Percentual de registros com 'Resultado' positivo - Low: {:.2f}%".format(def_descriptive_results(df_log_low)))
# Out:
# Percentual de registros com 'Resultado' positivo - High: 27.70%
# Percentual de registros com 'Resultado' positivo - Medium: 41.63%
# Percentual de registros com 'Resultado' positivo - Low: 34.10%

# %% [markdown]
# <b> Variável Target

# %%
# Criar a nova coluna 'Target' mapeando 'Negativo' para 0 e 'Positivo' para 1
df_log_high['Target'] = df_log_high['Resultado'].replace({'Negative': 0, 'Positive': 1})
df_log_medium['Target'] = df_log_medium['Resultado'].replace({'Negative': 0, 'Positive': 1})
df_log_low['Target'] = df_log_low['Resultado'].replace({'Negative': 0, 'Positive': 1})

# %%
print("Tamanho da base de dados - High:", df_log_high.shape)
print("Tamanho da base de dados - Medium:", df_log_medium.shape)
print("Tamanho da base de dados - Low:", df_log_low.shape)
# Out:
# Tamanho da base de dados - High: (63418, 18)
# Tamanho da base de dados - Medium: (66785, 18)
# Tamanho da base de dados - Low: (65546, 18)

# %%
protected_attribute = 'case:protected'
outcome_attribute = 'Target'
privileged_group = 0
unprivileged_group = 1


# Aplicar a função de resumo para cada base
summary_high = TrainTestSplit.Descriptive(df_log_high, "High", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_medium = TrainTestSplit.Descriptive(df_log_medium, "Medium", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_low = TrainTestSplit.Descriptive(df_log_low, "Low", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)

# Combinar todas as tabelas de resumo em uma única tabela
df_summary_table = pd.concat([summary_high, summary_medium, summary_low], axis=1)
df_summary_table
# Out:
#                                 High Medium     Low
# % Protected = 1               29.82%  9.88%  19.90%
# % Protected = 1 & Target = 1   3.03%  2.76%   3.65%
# Demographic Parity              0.25   0.15    0.20
# Disparate Impact                0.29   0.65    0.48
# Total                          10000  10000   10000
# Total Target = 0                7230   5837    6590
# Total Target = 1                2770   4163    3410

# %% [markdown]
# <b> Data de início e data de fim do case

# %%
def def_TimestampStartEnd(df):
    # Converter 'time:timestamp' para datetime
    df['time:timestamp'] = pd.to_datetime(df['time:timestamp'])

    # Calcular a data de início do case
    df['case_start_date'] = df.groupby('case:concept:name')['time:timestamp'].transform('min')

    # Calcular a data de fim do case
    df['case_end_date'] = df.groupby('case:concept:name')['time:timestamp'].transform('max')

    # Calcular o lead time em dias
    df['lead_time_days'] = (df['case_end_date'] - df['case_start_date']).dt.days

    return df

# %%
# Adicionar datas de início e fim do case
df_log_high = def_TimestampStartEnd(df_log_high)
df_log_medium = def_TimestampStartEnd(df_log_medium)
df_log_low = def_TimestampStartEnd(df_log_low)

# %% [markdown]
# <b>Atributos numéricos

# %%
#Idade
    #Infância (0-12 anos)
    #Adolescência (13-17 anos)
    #Juventude (18-24 anos)
    #Adulto jovem (25-34 anos)
    #Adulto de meia-idade (35-49 anos)
    #Pré-aposentadoria (50-64 anos)
    #Aposentado (65 anos ou mais)
    
# Categorizar idade
bins = [0, 12, 17, 24, 34, 49, 64, float('inf')]
labels = ['Childhood', 'Adolescence', 'Youth', 'Young Adult', 'Middle-Aged Adult', 'Pre-Retirement', 'Retired']

#Aplicar as bases de dados
df_log_high['age'] = pd.cut(df_log_high['case:age'], bins=bins, labels=labels, right=False)
df_log_medium['age'] = pd.cut(df_log_medium['case:age'], bins=bins, labels=labels, right=False)
df_log_low['age'] = pd.cut(df_log_low['case:age'], bins=bins, labels=labels, right=False)

# %%
# Anos de educação
    #Sem educação formal (0 anos)
    #Educação fundamental (1-8 anos)
    #Educação média (9-12 anos)
    #Educação superior (13 - 16 anos)
    #Pós-graduação (+17 anos)

bins = [-1, 0, 8, 12, 16, float('inf')]
labels = ['No Formal Education', 'Elementary Education', 'Secondary Education', 'Higher Education', 'Postgraduate Education']

#Aplicar as bases de dados
df_log_high['yearsOfEducation'] = pd.cut(df_log_high['case:yearsOfEducation'], bins=bins, labels=labels, right=False)
df_log_medium['yearsOfEducation'] = pd.cut(df_log_medium['case:yearsOfEducation'], bins=bins, labels=labels, right=False)
df_log_low['yearsOfEducation'] = pd.cut(df_log_low['case:yearsOfEducation'], bins=bins, labels=labels, right=False)

# %%
#Gerar dummies das categorizações
df_log_high = pd.get_dummies(df_log_high, columns=['age', 'yearsOfEducation'])
df_log_medium = pd.get_dummies(df_log_medium, columns=['age', 'yearsOfEducation'])
df_log_low = pd.get_dummies(df_log_low, columns=['age', 'yearsOfEducation'])

# %%
# Convertendo valores booleanos true/false para 1/0
bool_columns = ['age_Childhood', 'age_Adolescence', 'age_Youth', 'age_Young Adult', 'age_Middle-Aged Adult', 'age_Pre-Retirement', 'age_Retired',
                'yearsOfEducation_No Formal Education', 'yearsOfEducation_Elementary Education', 'yearsOfEducation_Secondary Education', 'yearsOfEducation_Higher Education', 'yearsOfEducation_Postgraduate Education'
               ]

df_log_high[bool_columns] = df_log_high[bool_columns].astype(int)
df_log_medium[bool_columns] = df_log_medium[bool_columns].astype(int)
df_log_low[bool_columns] = df_log_low[bool_columns].astype(int)

# %% [markdown]
# <b>Atributos categóricos

# %%
# Convertendo valores booleanos true/false para 1/0
atributos_categoricos = ['case:protected', 'case:german speaking', 'case:gender', 'case:citizen', 'case:married']

df_log_high[atributos_categoricos] = df_log_high[atributos_categoricos].astype(int)
df_log_medium[atributos_categoricos] = df_log_medium[atributos_categoricos].astype(int)
df_log_low[atributos_categoricos] = df_log_low[atributos_categoricos].astype(int)

# %%
#Extrair base tratada
df_log_high.to_csv(f'{name_prefix}_high-prep.csv')
df_log_medium.to_csv(f'{name_prefix}_medium-prep.csv')
df_log_low.to_csv(f'{name_prefix}_low-prep.csv')

# %% [markdown]
# <b> Trace encoding

# %%
log_high_transitions, log_high_all_transitions = TraceEncoding.ActivityTransitionsOneHotEncoding(df_log_high, var_id = 'case:case', var_activity = 'activity', var_timestamp = 'time:timestamp')
log_medium_transitions, log_medium_all_transitions = TraceEncoding.ActivityTransitionsOneHotEncoding(df_log_medium, var_id = 'case:case', var_activity = 'activity', var_timestamp = 'time:timestamp')
log_low_transitions, log_low_all_transitions = TraceEncoding.ActivityTransitionsOneHotEncoding(df_log_low, var_id = 'case:case', var_activity = 'activity', var_timestamp = 'time:timestamp')

# %%
#Trazer o encoding das transições para o dataframe
df_log_high = df_log_high.merge(log_high_transitions, on = 'case:case')
df_log_medium = df_log_medium.merge(log_medium_transitions, on = 'case:case')
df_log_low = df_log_low.merge(log_low_transitions, on = 'case:case')

# %% [markdown]
# <b> Resource encoding

# %%
log_high_resources, log_high_all_resources = ResourceEncoding.ResourceTransitionsOneHotEncoding(df_log_high, var_id = 'case:case', var_resource = 'resource', var_timestamp = 'time:timestamp')
log_medium_resources, log_medium_all_resources = ResourceEncoding.ResourceTransitionsOneHotEncoding(df_log_medium, var_id = 'case:case', var_resource = 'resource', var_timestamp = 'time:timestamp')
log_low_resources, log_low_all_resources = ResourceEncoding.ResourceTransitionsOneHotEncoding(df_log_low, var_id = 'case:case', var_resource = 'resource', var_timestamp = 'time:timestamp')

# %%
#Trazer o encoding das transições para o dataframe
df_log_high = df_log_high.merge(log_high_resources, on = 'case:case')
df_log_medium = df_log_medium.merge(log_medium_resources, on = 'case:case')
df_log_low = df_log_low.merge(log_low_resources, on = 'case:case')

# %%
#Mater apenas um registro por case
df_log_high = df_log_high.drop_duplicates(subset=['case:case']).drop(columns=['activity', 'resource', 'time', 'concept:name', 'time:timestamp', '@@index', 'case:concept:name', 'case:@@case_index'])
df_log_medium = df_log_medium.drop_duplicates(subset=['case:case']).drop(columns=['activity', 'resource', 'time', 'concept:name', 'time:timestamp', '@@index', 'case:concept:name', 'case:@@case_index'])
df_log_low = df_log_low.drop_duplicates(subset=['case:case']).drop(columns=['activity', 'resource', 'time', 'concept:name', 'time:timestamp', '@@index', 'case:concept:name', 'case:@@case_index'])

# %%
#Extrair base tratada
log_high.to_csv(f'{name_prefix}_high-tratada.csv')
log_medium.to_csv(f'{name_prefix}_medium-tratada.csv')
log_low.to_csv(f'{name_prefix}_low-tratada.csv')

# %% [markdown]
# <b>Eliminar Duplicidades/conflitos de casos

# %%
#Lista de variáveis que NÃO serão consideradas no modelo
exclude_variavel = [
             'case:case', 
             'case_start_date', 
             'case_end_date', 
             'lead_time_days', 
             'Resultado',
             #'Target', 
             #'case:protected',
             #'case:german speaking', 
             #'case:gender', 
             #'case:citizen', 
             #'case:married',
             'case:age', 
             'age_Childhood',
             'age_Adolescence', 
             'age_Youth', 
             #'age_Young Adult',
             #'age_Middle-Aged Adult', 
             #'age_Pre-Retirement', 
             #'age_Retired',
             'case:yearsOfEducation',
             'yearsOfEducation_No Formal Education',
             #'yearsOfEducation_Elementary Education',
             #'yearsOfEducation_Secondary Education',
             #'yearsOfEducation_Higher Education',
             #'yearsOfEducation_Postgraduate Education'
]

#Criar a lista 'variaveis', excluindo as atividades que contenha o resultado do case
todas_variaveis = set(df_log_high.columns) | set(df_log_medium.columns) | set(df_log_low.columns)
variaveis = [
    col for col in todas_variaveis 
    if col not in exclude_variavel
]

print(variaveis)
# Out:
# ['View The Property -> Hand In The Paperwork', 'Lawyer 1 -> Real Estate Agent 2', 'Real Estate Agent 5 -> Real Estate Agent 1', 'Real Estate Agent 1 -> Real Estate Agent 1', 'Real Estate Agent 5 -> Lawyer 1', 'Lawyer 2 -> Real Estate Agent 5', 'Hand In The Paperwork -> Check Paperwork', 'Hotline -> Hotline', 'Real Estate Agent 4 -> Lawyer 1', 'Real Estate Agent 1 -> Real Estate Agent 3', 'Real Estate Agent 2 -> Lawyer 2', 'Real Estate Agent 3 -> Lawyer 3', 'Screen Prospective Tenant -> Extensive Screening', 'Lawyer 3 -> Real Estate Agent 2', 'Real Estate Agent 1 -> Real Estate Agent 4', 'case:protected', 'age_Retired', 'age_Young Adult', 'Apply for Viewing Appointment -> Set Appointment', 'Hotline -> Real Estate Agent 4', 'Real Estate Agent 2 -> Real Estate Agent 5', 'age_Middle-Aged Adult', 'Real Estate Agent 1 -> Real Estate Agent 2', 'Real Estate Agent 3 -> Real Estate Agent 1', 'age_Pre-Retirement', 'Hotline -> Real Estate Agent 1', 'case:married', 'Lawyer 2 -> Real Estate Agent 4', 'case:gender', 'Real Estate Agent 5 -> Real Estate Agent 3', 'Real Estate Agent 4 -> Lawyer 3', 'Real Estate Agent 3 -> Lawyer 1', 'Real Estate Agent 3 -> Real Estate Agent 5', 'Real Estate Agent 1 -> Real Estate Agent 5', 'Lawyer 3 -> Real Estate Agent 1', 'yearsOfEducation_Elementary Education', 'Real Estate Agent 2 -> Lawyer 3', 'yearsOfEducation_Secondary Education', 'Real Estate Agent 5 -> Hotline', 'Lawyer 1 -> Real Estate Agent 4', 'Real Estate Agent 4 -> Real Estate Agent 2', 'Real Estate Agent 4 -> Real Estate Agent 3', 'Hotline -> Real Estate Agent 3', 'Real Estate Agent 1 -> Lawyer 1', 'Target', 'Real Estate Agent 3 -> Real Estate Agent 3', 'Check Paperwork -> Screen Prospective Tenant', 'yearsOfEducation_Postgraduate Education', 'yearsOfEducation_Higher Education', 'Real Estate Agent 2 -> Real Estate Agent 4', 'case:german speaking', 'Real Estate Agent 2 -> Real Estate Agent 1', 'Real Estate Agent 2 -> Hotline', 'case:citizen', 'Lawyer 2 -> Real Estate Agent 1', 'Real Estate Agent 3 -> Real Estate Agent 2', 'Lawyer 1 -> Real Estate Agent 3', 'Real Estate Agent 3 -> Hotline', 'Lawyer 1 -> Real Estate Agent 1', 'Real Estate Agent 4 -> Real Estate Agent 4', 'Lawyer 2 -> Real Estate Agent 3', 'Real Estate Agent 5 -> Lawyer 2', 'Real Estate Agent 3 -> Real Estate Agent 4', 'Real Estate Agent 5 -> Real Estate Agent 5', 'Real Estate Agent 2 -> Real Estate Agent 2', 'Real Estate Agent 4 -> Real Estate Agent 1', 'Real Estate Agent 2 -> Real Estate Agent 3', 'Real Estate Agent 1 -> Lawyer 2', 'Lawyer 3 -> Real Estate Agent 3', 'Real Estate Agent 5 -> Real Estate Agent 4', 'Hotline -> Real Estate Agent 2', 'Real Estate Agent 5 -> Real Estate Agent 2', 'Real Estate Agent 4 -> Lawyer 2', 'Real Estate Agent 1 -> Hotline', 'Lawyer 2 -> Real Estate Agent 2', 'Real Estate Agent 3 -> Lawyer 2', 'Lawyer 1 -> Real Estate Agent 5', 'Set Appointment -> View The Property', 'Real Estate Agent 1 -> Lawyer 3', 'Lawyer 3 -> Real Estate Agent 4', 'Hotline -> Real Estate Agent 5', 'Real Estate Agent 4 -> Hotline', 'Real Estate Agent 2 -> Lawyer 1', 'Lawyer 3 -> Real Estate Agent 5', 'Real Estate Agent 5 -> Lawyer 3', 'Real Estate Agent 4 -> Real Estate Agent 5']

# %% [markdown]
# Identificar e eliminar registros conflitantes na base de dados

# %%
conflicting_groups_high, conflicting_cases_high, df_log_high_cleaned = DataPrep.KeepFirstConflictingCases(df_log_high, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')
conflicting_groups_medium, conflicting_cases_medium, df_log_medium_cleaned = DataPrep.KeepFirstConflictingCases(df_log_medium, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')
conflicting_groups_low, conflicting_cases_low, df_log_low_cleaned = DataPrep.KeepFirstConflictingCases(df_log_low, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')

# %%
df_log_high = df_log_high_cleaned.copy()
df_log_medium = df_log_medium_cleaned.copy()
df_log_low = df_log_low_cleaned.copy()

# %%
print("Tamanho da base de dados - High:", df_log_high.shape)
print("Tamanho da base de dados - Medium:", df_log_medium.shape)
print("Tamanho da base de dados - Low:", df_log_low.shape)
# Out:
# Tamanho da base de dados - High: (9136, 97)
# Tamanho da base de dados - Medium: (9444, 97)
# Tamanho da base de dados - Low: (9348, 97)

# %% [markdown]
# Identificar e eliminar duplicidades de registros na base de dados

# %%
# Encontrar casos duplicados
df_log_high_duplicates, df_log_high_merged, df_log_high_cleaned = DataPrep.KeepFirstDuplicateCases(df_log_high, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')
df_log_medium_duplicates, df_log_medium_merged, df_log_medium_cleaned = DataPrep.KeepFirstDuplicateCases(df_log_medium, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')
df_log_low_duplicates, df_log_low_merged, df_log_low_cleaned = DataPrep.KeepFirstDuplicateCases(df_log_low, variaveis, var_timestamp = 'time:timestamp', var_target = 'Target', var_id = 'case:case', var_date = 'case_start_date')

# %%
df_log_high = df_log_high_cleaned.copy()
df_log_medium = df_log_medium_cleaned.copy()
df_log_low = df_log_low_cleaned.copy()

# %%
print("Tamanho da base de dados - High:", df_log_high.shape)
print("Tamanho da base de dados - Medium:", df_log_medium.shape)
print("Tamanho da base de dados - Low:", df_log_low.shape)
# Out:
# Tamanho da base de dados - High: (9026, 97)
# Tamanho da base de dados - Medium: (9332, 97)
# Tamanho da base de dados - Low: (9243, 97)

# %%
#Extrair base tratada
df_log_high.to_csv(f'{name_prefix}_high-tratada-semdpl.csv')
df_log_medium.to_csv(f'{name_prefix}_medium-tratada-semdpl.csv')
df_log_low.to_csv(f'{name_prefix}_low-tratada-semdpl.csv')

# %%
protected_attribute = 'case:protected'
outcome_attribute = 'Target'
privileged_group = 0
unprivileged_group = 1


# Aplicar a função de resumo para cada base
summary_high = TrainTestSplit.Descriptive(df_log_high, "High", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_medium = TrainTestSplit.Descriptive(df_log_medium, "Medium", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_low = TrainTestSplit.Descriptive(df_log_low, "Low", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)

# Combinar todas as tabelas de resumo em uma única tabela
df_summary_table = pd.concat([summary_high, summary_medium, summary_low], axis=1)
df_summary_table
# Out:
#                                 High Medium     Low
# % Protected = 1               26.89%  9.94%  18.73%
# % Protected = 1 & Target = 1   3.35%  2.96%   3.94%
# Demographic Parity              0.25   0.16    0.19
# Disparate Impact                0.33   0.65    0.52
# Total                           9026   9332    9243
# Total Target = 0                6269   5197    5851
# Total Target = 1                2757   4135    3392

# %% [markdown]
# <b> Divisão da base em treino/teste

# %%
# Aplicar a divisão entre treino e teste
  #Pela data de início do case
df_train_high, df_test_high = TrainTestSplit.SplitDataTemporal(df_log_high, test_size=0.3, var_date = 'case_start_date')
df_train_medium, df_test_medium = TrainTestSplit.SplitDataTemporal(df_log_medium, test_size=0.3, var_date = 'case_start_date')
df_train_low, df_test_low = TrainTestSplit.SplitDataTemporal(df_log_low, test_size=0.3, var_date = 'case_start_date')

# %%
#Copia dos dataframe para resolver problema de fragmentação
df_train_high = df_train_high.copy()
df_test_high = df_test_high.copy()
df_train_medium = df_train_medium.copy()
df_test_medium = df_test_medium.copy()
df_train_low = df_train_low.copy()
df_test_low = df_test_low.copy()

# %%
protected_attribute = 'case:protected'
outcome_attribute = 'Target'
privileged_group = 0
unprivileged_group = 1


# Aplicar a função de resumo para cada base
summary_high = TrainTestSplit.DescriptiveTrainTest(df_train_high, df_test_high, "High", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_medium = TrainTestSplit.DescriptiveTrainTest(df_train_medium, df_test_medium, "Medium", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)
summary_low = TrainTestSplit.DescriptiveTrainTest(df_train_low, df_test_low, "Low", outcome_attribute, protected_attribute, privileged_group, unprivileged_group)

# Combinar todas as tabelas de resumo em uma única tabela
df_summary_table = pd.concat([summary_high, summary_medium, summary_low], axis=1)
df_summary_table
# Out:
#                              High - Train High - Test Medium - Train  \
# Total                                6318        2708           6532
# % Target = 0                       69.75%      68.76%         55.62%
# % Target = 1                       30.25%      31.24%         44.38%
# % Protected = 1                    27.13%      26.33%         10.06%
# % Protected = 1 & Target = 1        3.36%       3.32%          3.09%
# Disparate Impact                     0.34        0.33           0.67
#
#                              Medium - Test Low - Train Low - Test
# Total                                 2800        6470       2773
# % Target = 0                        55.86%      63.15%     63.65%
# % Target = 1                        44.14%      36.85%     36.35%
# % Protected = 1                      9.68%      19.13%     17.78%
# % Protected = 1 & Target = 1         2.64%       4.13%      3.50%
# Disparate Impact                      0.59        0.53       0.49

# %% [markdown]
# <b> Definição das variáveis

# %%
# Remover 'Target' da lista de variáveis, caso esteja presente
variaveis = [var for var in variaveis if var != 'Target']

# Selecionando características e o alvo
variaveis_high = [var for var in variaveis if var in df_log_high.columns]
X_train_high, y_train_high = df_train_high[variaveis_high], df_train_high['Target']
X_test_high, y_test_high = df_test_high[variaveis_high], df_test_high['Target']

variaveis_medium = [var for var in variaveis if var in df_log_medium.columns]
X_train_medium, y_train_medium = df_train_medium[variaveis_medium], df_train_medium['Target']
X_test_medium, y_test_medium = df_test_medium[variaveis_medium], df_test_medium['Target']

variaveis_low = [var for var in variaveis if var in df_log_low.columns]
X_train_low, y_train_low = df_train_low[variaveis_low], df_train_low['Target']
X_test_low, y_test_low = df_test_low[variaveis_low], df_test_low['Target']

# %%
#Verificar a existência de colunas que NÃO estão no formato numérico
print("High:", X_train_high.select_dtypes(exclude=['number']).columns)
print("Medium:", X_train_medium.select_dtypes(exclude=['number']).columns)
print("Low:", X_train_low.select_dtypes(exclude=['number']).columns)
# Out:
# High: Index([], dtype='object')
# Medium: Index([], dtype='object')
# Low: Index([], dtype='object')

# %%
print("Dimensionalidade - High:", X_train_high.shape)
print("Dimensionalidad - Medium:", X_train_medium.shape)
print("Dimensionalidad - Low:", X_train_low.shape)
# Out:
# Dimensionalidade - High: (6318, 85)
# Dimensionalidad - Medium: (6532, 85)
# Dimensionalidad - Low: (6470, 85)

# %% [markdown]
# ## Predictive Process Monitoring

# %% [markdown]
# ### 1. Baseline model

# %% [markdown]
# <b> Random Florest Classifier

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = MachineLearning.RandomFlorestOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = MachineLearning.RandomFlorestOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = MachineLearning.RandomFlorestOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, num_trials=50)

# %%
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'n_estimators': 50, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.7097189110359706}
# Medium - Parâmetros: {'n_estimators': 144, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.7062323859319823}
# Low - Parâmetros: {'n_estimators': 134, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.706592438781015}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Baseline', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Baseline', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Baseline', privileged_group, unprivileged_group)

df_metrics = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
def get_feature_importance(explanations, feature_names):
    """
    Calcula a importância média das variáveis a partir das explicações LIME.
    """
    feature_importances = np.zeros(len(feature_names))
    for explanation in explanations:
        for feature, importance in explanation.local_exp[1]:  # 1 é a classe alvo
            feature_importances[feature] += importance
    feature_importances /= len(explanations)
    return feature_importances

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_baseline_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# case:protected                                           0.119817
# age_Young Adult                                          0.052245
# Real Estate Agent 5 -> Lawyer 3                         -0.035617
# Real Estate Agent 4 -> Real Estate Agent 3              -0.029021
# Real Estate Agent 3 -> Real Estate Agent 3               0.025022
# ...                                                           ...
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# Set Appointment -> View The Property                     0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
# View The Property -> Hand In The Paperwork               0.000000
#
#                                                   Importance_Medium  \
# Feature
# case:protected                                             0.054624
# age_Young Adult                                           -0.003475
# Real Estate Agent 5 -> Lawyer 3                           -0.000121
# Real Estate Agent 4 -> Real Estate Agent 3                -0.000362
# Real Estate Agent 3 -> Real Estate Agent 3                 0.004723
# ...                                                             ...
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# Set Appointment -> View The Property                       0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
# View The Property -> Hand In The Paperwork                 0.000000
#
#                                                   Importance_Low
# Feature
# case:protected                                          0.082915
# age_Young Adult                                         0.006880
# Real Estate Agent 5 -> Lawyer 3                         0.020786
# Real Estate Agent 4 -> Real Estate Agent 3              0.027337
# Real Estate Agent 3 -> Real Estate Agent 3             -0.023112
# ...                                                          ...
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# Set Appointment -> View The Property                    0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
# View The Property -> Hand In The Paperwork              0.000000
#
# [85 rows x 3 columns]

# %% [markdown]
# ### 2. Estratégia para Fairness

# %% [markdown]
# <b> 2.1 Reweighing

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = AIF360.PreReweighingRandomFlorestOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, protected_attribute, alpha = 0.1, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = AIF360.PreReweighingRandomFlorestOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, protected_attribute, alpha = 0.1, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = AIF360.PreReweighingRandomFlorestOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, protected_attribute, alpha = 0.1, num_trials=50)

# %%
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'n_estimators': 91, 'max_depth': 20, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.6067427735815447}
# Medium - Parâmetros: {'n_estimators': 82, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.6471016588481742}
# Low - Parâmetros: {'n_estimators': 85, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.7551641468393523}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Preprocessing: Reweighing', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Preprocessing: Reweighing', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Preprocessing: Reweighing', privileged_group, unprivileged_group)

df_metrics_Rew = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics = pd.concat([df_metrics, df_metrics_Rew], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_pre_rew_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# Lawyer 3 -> Real Estate Agent 4                         -0.043058
# age_Young Adult                                          0.037083
# Real Estate Agent 4 -> Real Estate Agent 3              -0.031817
# Real Estate Agent 5 -> Lawyer 3                         -0.031626
# Real Estate Agent 4 -> Lawyer 2                         -0.023116
# ...                                                           ...
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# Set Appointment -> View The Property                     0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
# View The Property -> Hand In The Paperwork               0.000000
#
#                                                   Importance_Medium  \
# Feature
# Lawyer 3 -> Real Estate Agent 4                           -0.049772
# age_Young Adult                                           -0.007515
# Real Estate Agent 4 -> Real Estate Agent 3                 0.008979
# Real Estate Agent 5 -> Lawyer 3                            0.000977
# Real Estate Agent 4 -> Lawyer 2                           -0.004961
# ...                                                             ...
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# Set Appointment -> View The Property                       0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
# View The Property -> Hand In The Paperwork                 0.000000
#
#                                                   Importance_Low
# Feature
# Lawyer 3 -> Real Estate Agent 4                         0.013055
# age_Young Adult                                         0.005438
# Real Estate Agent 4 -> Real Estate Agent 3              0.020209
# Real Estate Agent 5 -> Lawyer 3                         0.012315
# Real Estate Agent 4 -> Lawyer 2                        -0.007857
# ...                                                          ...
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# Set Appointment -> View The Property                    0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
# View The Property -> Hand In The Paperwork              0.000000
#
# [85 rows x 3 columns]

# %% [markdown]
# <b> 2.2 Disparate Impact Remover

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = AIF360.PreDisparateImpactRemoverRandomFlorestOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, protected_attribute, alpha = 0.1, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = AIF360.PreDisparateImpactRemoverRandomFlorestOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, protected_attribute, alpha = 0.1, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = AIF360.PreDisparateImpactRemoverRandomFlorestOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, protected_attribute, alpha = 0.1, num_trials=50)

# %%
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'n_estimators': 187, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.9375267847930147}
# Medium - Parâmetros: {'n_estimators': 65, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.9926907870911537}
# Low - Parâmetros: {'n_estimators': 68, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.94153205391074}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Preprocessing: Disparate Impact Remover', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Preprocessing: Disparate Impact Remover', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Preprocessing: Disparate Impact Remover', privileged_group, unprivileged_group)

df_metrics_Dir = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics = pd.concat([df_metrics, df_metrics_Dir], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_pre_dir_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# case:protected                                           0.057662
# Real Estate Agent 5 -> Lawyer 3                         -0.025381
# Lawyer 3 -> Real Estate Agent 4                         -0.018553
# Real Estate Agent 4 -> Lawyer 2                         -0.017311
# Lawyer 1 -> Real Estate Agent 3                         -0.014294
# ...                                                           ...
# Set Appointment -> View The Property                     0.000000
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
# View The Property -> Hand In The Paperwork               0.000000
#
#                                                   Importance_Medium  \
# Feature
# case:protected                                             0.021159
# Real Estate Agent 5 -> Lawyer 3                           -0.002987
# Lawyer 3 -> Real Estate Agent 4                           -0.033809
# Real Estate Agent 4 -> Lawyer 2                            0.001216
# Lawyer 1 -> Real Estate Agent 3                           -0.005161
# ...                                                             ...
# Set Appointment -> View The Property                       0.000000
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
# View The Property -> Hand In The Paperwork                 0.000000
#
#                                                   Importance_Low
# Feature
# case:protected                                          0.033944
# Real Estate Agent 5 -> Lawyer 3                         0.002420
# Lawyer 3 -> Real Estate Agent 4                         0.006362
# Real Estate Agent 4 -> Lawyer 2                        -0.005867
# Lawyer 1 -> Real Estate Agent 3                         0.000938
# ...                                                          ...
# Set Appointment -> View The Property                    0.000000
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
# View The Property -> Hand In The Paperwork              0.000000
#
# [85 rows x 3 columns]

# %% [markdown]
# <b> 2.3 Adversarial Debiasing

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = AIF360.InAdversarialDebiasingOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, protected_attribute, alpha = 0.1, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = AIF360.InAdversarialDebiasingOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, protected_attribute, alpha = 0.1, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = AIF360.InAdversarialDebiasingOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, protected_attribute, alpha = 0.1, num_trials=50)
# Out:
# WARNING:tensorflow:From C:\Users\micka\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\micka\anaconda3\Lib\site-packages\aif360\algorithms\inprocessing\adversarial_debiasing.py:164: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# epoch 0; iter: 0; batch classifier loss: 0.733478; batch adversarial loss: 0.852247
# epoch 1; iter: 0; batch classifier loss: 0.579358; batch adversarial loss: 0.790194
# epoch 2; iter: 0; batch classifier loss: 0.590461; batch adversarial loss: 0.733888
# epoch 3; iter: 0; batch classifier loss: 0.589657; batch adversarial loss: 0.702168
# epoch 4; iter: 0; batch classifier loss: 0.542075; batch adversarial loss: 0.676333
# epoch 5; iter: 0; batch classifier loss: 0.524721; batch adversarial loss: 0.652685
# epoch 6; iter: 0; batch classifier loss: 0.500178; batch adversarial loss: 0.670539
# epoch 7; iter: 0; batch classifier loss: 0.531165; batch adversarial loss: 0.639276
# epoch 8; iter: 0; batch classifier loss: 0.586628; batch adversarial loss: 0.636499
# epoch 9; iter: 0; batch classifier loss: 0.517478; batch adversarial loss: 0.629663
# epoch 10; iter: 0; batch classifier loss: 0.477977; batch adversarial loss: 0.629373
# epoch 11; iter: 0; batch classifier loss: 0.473026; batch adversarial loss: 0.656430
# epoch 12; iter: 0; batch classifier loss: 0.481756; batch adversarial loss: 0.589028
# epoch 13; iter: 0; batch classifier loss: 0.528342; batch adversarial loss: 0.605338
# epoch 14; iter: 0; batch classifier loss: 0.494646; batch adversarial loss: 0.610566
# epoch 15; iter: 0; batch classifier loss: 0.506254; batch adversarial loss: 0.569295
# epoch 16; iter: 0; batch classifier loss: 0.492159; batch adversarial loss: 0.573286
# epoch 17; iter: 0; batch classifier loss: 0.470430; batch adversarial loss: 0.605330
# epoch 18; iter: 0; batch classifier loss: 0.513647; batch adversarial loss: 0.580791
# epoch 19; iter: 0; batch classifier loss: 0.497050; batch adversarial loss: 0.520985
# epoch 20; iter: 0; batch classifier loss: 0.488376; batch adversarial loss: 0.539735
# epoch 21; iter: 0; batch classifier loss: 0.482359; batch adversarial loss: 0.529753
# epoch 22; iter: 0; batch classifier loss: 0.496843; batch adversarial loss: 0.541727
# epoch 23; iter: 0; batch classifier loss: 0.575801; batch adversarial loss: 0.534127
# epoch 24; iter: 0; batch classifier loss: 0.409545; batch adversarial loss: 0.512876
# epoch 25; iter: 0; batch classifier loss: 0.413985; batch adversarial loss: 0.576641
# epoch 26; iter: 0; batch classifier loss: 0.444001; batch adversarial loss: 0.583450
# epoch 27; iter: 0; batch classifier loss: 0.419517; batch adversarial loss: 0.548888
# epoch 28; iter: 0; batch classifier loss: 0.395355; batch adversarial loss: 0.602488
# epoch 29; iter: 0; batch classifier loss: 0.445122; batch adversarial loss: 0.504460
# epoch 30; iter: 0; batch classifier loss: 0.416245; batch adversarial loss: 0.515121
# epoch 31; iter: 0; batch classifier loss: 0.430305; batch adversarial loss: 0.533536
# epoch 32; iter: 0; batch classifier loss: 0.414183; batch adversarial loss: 0.612019
# epoch 33; iter: 0; batch classifier loss: 0.410950; batch adversarial loss: 0.544883
# epoch 34; iter: 0; batch classifier loss: 0.385769; batch adversarial loss: 0.592691
# epoch 35; iter: 0; batch classifier loss: 0.433410; batch adversarial loss: 0.643489
# epoch 36; iter: 0; batch classifier loss: 0.459721; batch adversarial loss: 0.680462
# epoch 37; iter: 0; batch classifier loss: 0.477130; batch adversarial loss: 0.591989
# epoch 38; iter: 0; batch classifier loss: 0.387837; batch adversarial loss: 0.656506
# epoch 39; iter: 0; batch classifier loss: 0.450911; batch adversarial loss: 0.620989
# epoch 40; iter: 0; batch classifier loss: 0.381104; batch adversarial loss: 0.517748
# epoch 41; iter: 0; batch classifier loss: 0.382858; batch adversarial loss: 0.581281
# epoch 42; iter: 0; batch classifier loss: 0.450213; batch adversarial loss: 0.667578
# epoch 43; iter: 0; batch classifier loss: 0.465182; batch adversarial loss: 0.654480
# epoch 44; iter: 0; batch classifier loss: 0.499151; batch adversarial loss: 0.650603
# epoch 45; iter: 0; batch classifier loss: 0.446472; batch adversarial loss: 0.569970
# epoch 46; iter: 0; batch classifier loss: 0.393412; batch adversarial loss: 0.539380
# epoch 47; iter: 0; batch classifier loss: 0.400692; batch adversarial loss: 0.593627
# epoch 48; iter: 0; batch classifier loss: 0.432141; batch adversarial loss: 0.660192
# epoch 49; iter: 0; batch classifier loss: 0.440185; batch adversarial loss: 0.697396
# epoch 50; iter: 0; batch classifier loss: 0.383740; batch adversarial loss: 0.539455
# epoch 51; iter: 0; batch classifier loss: 0.465320; batch adversarial loss: 0.605124
# epoch 52; iter: 0; batch classifier loss: 0.446010; batch adversarial loss: 0.631390
# epoch 53; iter: 0; batch classifier loss: 0.588395; batch adversarial loss: 0.602541
# epoch 54; iter: 0; batch classifier loss: 0.513716; batch adversarial loss: 0.637002
# epoch 55; iter: 0; batch classifier loss: 0.568969; batch adversarial loss: 0.634286
# epoch 56; iter: 0; batch classifier loss: 0.470630; batch adversarial loss: 0.607217
# epoch 57; iter: 0; batch classifier loss: 0.463506; batch adversarial loss: 0.588001
# epoch 58; iter: 0; batch classifier loss: 0.431059; batch adversarial loss: 0.536627
# epoch 59; iter: 0; batch classifier loss: 0.314334; batch adversarial loss: 0.578223
# epoch 60; iter: 0; batch classifier loss: 0.337064; batch adversarial loss: 0.592694
# epoch 61; iter: 0; batch classifier loss: 0.362192; batch adversarial loss: 0.599530
# epoch 62; iter: 0; batch classifier loss: 0.374310; batch adversarial loss: 0.547041
# epoch 63; iter: 0; batch classifier loss: 0.376346; batch adversarial loss: 0.577631
# epoch 64; iter: 0; batch classifier loss: 0.351174; batch adversarial loss: 0.586299
# epoch 65; iter: 0; batch classifier loss: 0.311966; batch adversarial loss: 0.556691
# epoch 66; iter: 0; batch classifier loss: 0.330188; batch adversarial loss: 0.492460
# epoch 67; iter: 0; batch classifier loss: 0.381878; batch adversarial loss: 0.560006
# epoch 68; iter: 0; batch classifier loss: 0.280105; batch adversarial loss: 0.584948
# epoch 69; iter: 0; batch classifier loss: 0.345314; batch adversarial loss: 0.619013
# epoch 70; iter: 0; batch classifier loss: 0.323834; batch adversarial loss: 0.513303
# epoch 71; iter: 0; batch classifier loss: 0.297407; batch adversarial loss: 0.599181
# epoch 72; iter: 0; batch classifier loss: 0.284228; batch adversarial loss: 0.505408
# epoch 73; iter: 0; batch classifier loss: 0.310771; batch adversarial loss: 0.579825
# epoch 74; iter: 0; batch classifier loss: 0.262843; batch adversarial loss: 0.611307
# epoch 75; iter: 0; batch classifier loss: 0.281289; batch adversarial loss: 0.568545
# epoch 76; iter: 0; batch classifier loss: 0.313738; batch adversarial loss: 0.521800
# epoch 77; iter: 0; batch classifier loss: 0.322393; batch adversarial loss: 0.586289
# epoch 78; iter: 0; batch classifier loss: 0.335937; batch adversarial loss: 0.566745
# epoch 79; iter: 0; batch classifier loss: 0.280043; batch adversarial loss: 0.580916
# epoch 80; iter: 0; batch classifier loss: 0.263892; batch adversarial loss: 0.605690
# epoch 81; iter: 0; batch classifier loss: 0.259016; batch adversarial loss: 0.580136
# epoch 82; iter: 0; batch classifier loss: 0.286305; batch adversarial loss: 0.621733
# epoch 83; iter: 0; batch classifier loss: 0.275568; batch adversarial loss: 0.557627
# epoch 84; iter: 0; batch classifier loss: 0.295800; batch adversarial loss: 0.553111
# epoch 85; iter: 0; batch classifier loss: 0.311874; batch adversarial loss: 0.559453
# epoch 86; iter: 0; batch classifier loss: 0.314286; batch adversarial loss: 0.601768
# epoch 87; iter: 0; batch classifier loss: 0.339279; batch adversarial loss: 0.619550
# epoch 88; iter: 0; batch classifier loss: 0.304518; batch adversarial loss: 0.544286
# epoch 89; iter: 0; batch classifier loss: 0.260904; batch adversarial loss: 0.569054
# epoch 90; iter: 0; batch classifier loss: 0.266276; batch adversarial loss: 0.601667
# epoch 91; iter: 0; batch classifier loss: 0.324323; batch adversarial loss: 0.535484
# epoch 92; iter: 0; batch classifier loss: 0.293995; batch adversarial loss: 0.547448
# epoch 93; iter: 0; batch classifier loss: 0.272680; batch adversarial loss: 0.601197
# epoch 94; iter: 0; batch classifier loss: 0.251506; batch adversarial loss: 0.591910
# epoch 95; iter: 0; batch classifier loss: 0.303735; batch adversarial loss: 0.605156
# epoch 96; iter: 0; batch classifier loss: 0.186300; batch adversarial loss: 0.597597
# epoch 97; iter: 0; batch classifier loss: 0.206901; batch adversarial loss: 0.632874
# epoch 98; iter: 0; batch classifier loss: 0.305642; batch adversarial loss: 0.560417
# epoch 99; iter: 0; batch classifier loss: 0.268767; batch adversarial loss: 0.559273
# epoch 0; iter: 0; batch classifier loss: 0.782897; batch adversarial loss: 0.861270
# epoch 1; iter: 0; batch classifier loss: 0.949778; batch adversarial loss: 0.896181
# epoch 2; iter: 0; batch classifier loss: 0.834709; batch adversarial loss: 0.815626
# epoch 3; iter: 0; batch classifier loss: 0.749317; batch adversarial loss: 0.801039
# epoch 4; iter: 0; batch classifier loss: 0.725578; batch adversarial loss: 0.753348
# epoch 5; iter: 0; batch classifier loss: 0.716511; batch adversarial loss: 0.687835
# epoch 6; iter: 0; batch classifier loss: 0.581841; batch adversarial loss: 0.681080
# epoch 7; iter: 0; batch classifier loss: 0.543638; batch adversarial loss: 0.634394
# epoch 8; iter: 0; batch classifier loss: 0.591648; batch adversarial loss: 0.639929
# epoch 9; iter: 0; batch classifier loss: 0.551995; batch adversarial loss: 0.618445
# epoch 10; iter: 0; batch classifier loss: 0.493768; batch adversarial loss: 0.619948
# epoch 11; iter: 0; batch classifier loss: 0.466044; batch adversarial loss: 0.649590
# epoch 12; iter: 0; batch classifier loss: 0.533631; batch adversarial loss: 0.568444
# epoch 13; iter: 0; batch classifier loss: 0.507335; batch adversarial loss: 0.598751
# epoch 14; iter: 0; batch classifier loss: 0.526026; batch adversarial loss: 0.598059
# epoch 15; iter: 0; batch classifier loss: 0.509115; batch adversarial loss: 0.563076
# epoch 16; iter: 0; batch classifier loss: 0.490960; batch adversarial loss: 0.581090
# epoch 17; iter: 0; batch classifier loss: 0.517773; batch adversarial loss: 0.624812
# epoch 18; iter: 0; batch classifier loss: 0.499385; batch adversarial loss: 0.623500
# epoch 19; iter: 0; batch classifier loss: 0.499197; batch adversarial loss: 0.575215
# epoch 20; iter: 0; batch classifier loss: 0.498662; batch adversarial loss: 0.601820
# epoch 21; iter: 0; batch classifier loss: 0.501214; batch adversarial loss: 0.586596
# epoch 22; iter: 0; batch classifier loss: 0.547423; batch adversarial loss: 0.605496
# epoch 23; iter: 0; batch classifier loss: 0.644396; batch adversarial loss: 0.636277
# epoch 24; iter: 0; batch classifier loss: 0.567452; batch adversarial loss: 0.599370
# epoch 25; iter: 0; batch classifier loss: 0.572978; batch adversarial loss: 0.668041
# epoch 26; iter: 0; batch classifier loss: 0.705587; batch adversarial loss: 0.690505
# epoch 27; iter: 0; batch classifier loss: 0.822108; batch adversarial loss: 0.678549
# epoch 28; iter: 0; batch classifier loss: 0.933041; batch adversarial loss: 0.733078
# epoch 29; iter: 0; batch classifier loss: 0.793316; batch adversarial loss: 0.599454
# epoch 30; iter: 0; batch classifier loss: 0.678334; batch adversarial loss: 0.570000
# epoch 31; iter: 0; batch classifier loss: 0.644689; batch adversarial loss: 0.584003
# epoch 32; iter: 0; batch classifier loss: 0.610541; batch adversarial loss: 0.640329
# epoch 33; iter: 0; batch classifier loss: 0.517638; batch adversarial loss: 0.559472
# epoch 34; iter: 0; batch classifier loss: 0.494767; batch adversarial loss: 0.579630
# epoch 35; iter: 0; batch classifier loss: 0.463888; batch adversarial loss: 0.599742
# epoch 36; iter: 0; batch classifier loss: 0.483026; batch adversarial loss: 0.628919
# epoch 37; iter: 0; batch classifier loss: 0.514395; batch adversarial loss: 0.554015
# epoch 38; iter: 0; batch classifier loss: 0.430543; batch adversarial loss: 0.603513
# epoch 39; iter: 0; batch classifier loss: 0.511086; batch adversarial loss: 0.570594
# epoch 40; iter: 0; batch classifier loss: 0.437422; batch adversarial loss: 0.497912
# epoch 41; iter: 0; batch classifier loss: 0.494904; batch adversarial loss: 0.571783
# epoch 42; iter: 0; batch classifier loss: 0.515005; batch adversarial loss: 0.615520
# epoch 43; iter: 0; batch classifier loss: 0.524573; batch adversarial loss: 0.636681
# epoch 44; iter: 0; batch classifier loss: 0.644625; batch adversarial loss: 0.632919
# epoch 45; iter: 0; batch classifier loss: 0.662800; batch adversarial loss: 0.601971
# epoch 46; iter: 0; batch classifier loss: 0.742445; batch adversarial loss: 0.546931
# epoch 47; iter: 0; batch classifier loss: 0.827829; batch adversarial loss: 0.595519
# epoch 48; iter: 0; batch classifier loss: 0.876030; batch adversarial loss: 0.644589
# epoch 49; iter: 0; batch classifier loss: 0.463674; batch adversarial loss: 0.661896
# epoch 50; iter: 0; batch classifier loss: 0.452007; batch adversarial loss: 0.537338
# epoch 51; iter: 0; batch classifier loss: 0.428285; batch adversarial loss: 0.591685
# epoch 52; iter: 0; batch classifier loss: 0.415269; batch adversarial loss: 0.606072
# epoch 53; iter: 0; batch classifier loss: 0.539928; batch adversarial loss: 0.576649
# epoch 54; iter: 0; batch classifier loss: 0.478493; batch adversarial loss: 0.608135
# epoch 55; iter: 0; batch classifier loss: 0.457811; batch adversarial loss: 0.621765
# epoch 56; iter: 0; batch classifier loss: 0.456700; batch adversarial loss: 0.598893
# epoch 57; iter: 0; batch classifier loss: 0.518468; batch adversarial loss: 0.588462
# epoch 58; iter: 0; batch classifier loss: 0.512225; batch adversarial loss: 0.540879
# epoch 59; iter: 0; batch classifier loss: 0.414736; batch adversarial loss: 0.582502
# epoch 60; iter: 0; batch classifier loss: 0.462420; batch adversarial loss: 0.597936
# epoch 61; iter: 0; batch classifier loss: 0.471424; batch adversarial loss: 0.606117
# epoch 62; iter: 0; batch classifier loss: 0.502800; batch adversarial loss: 0.555875
# epoch 63; iter: 0; batch classifier loss: 0.502443; batch adversarial loss: 0.582308
# epoch 64; iter: 0; batch classifier loss: 0.505156; batch adversarial loss: 0.594417
# epoch 65; iter: 0; batch classifier loss: 0.451731; batch adversarial loss: 0.561365
# epoch 66; iter: 0; batch classifier loss: 0.428025; batch adversarial loss: 0.493710
# epoch 67; iter: 0; batch classifier loss: 0.500808; batch adversarial loss: 0.551515
# epoch 68; iter: 0; batch classifier loss: 0.382260; batch adversarial loss: 0.593544
# epoch 69; iter: 0; batch classifier loss: 0.443616; batch adversarial loss: 0.617334
# epoch 70; iter: 0; batch classifier loss: 0.454548; batch adversarial loss: 0.518670
# epoch 71; iter: 0; batch classifier loss: 0.428687; batch adversarial loss: 0.603481
# epoch 72; iter: 0; batch classifier loss: 0.389932; batch adversarial loss: 0.517391
# epoch 73; iter: 0; batch classifier loss: 0.444899; batch adversarial loss: 0.583989
# epoch 74; iter: 0; batch classifier loss: 0.391233; batch adversarial loss: 0.601087
# epoch 75; iter: 0; batch classifier loss: 0.415766; batch adversarial loss: 0.576367
# epoch 76; iter: 0; batch classifier loss: 0.482295; batch adversarial loss: 0.521277
# epoch 77; iter: 0; batch classifier loss: 0.426090; batch adversarial loss: 0.588740
# epoch 78; iter: 0; batch classifier loss: 0.417018; batch adversarial loss: 0.574320
# epoch 79; iter: 0; batch classifier loss: 0.462697; batch adversarial loss: 0.585148
# epoch 80; iter: 0; batch classifier loss: 0.411823; batch adversarial loss: 0.605622
# epoch 81; iter: 0; batch classifier loss: 0.398693; batch adversarial loss: 0.586121
# epoch 82; iter: 0; batch classifier loss: 0.385849; batch adversarial loss: 0.625116
# epoch 83; iter: 0; batch classifier loss: 0.471332; batch adversarial loss: 0.565518
# epoch 84; iter: 0; batch classifier loss: 0.472854; batch adversarial loss: 0.563566
# epoch 85; iter: 0; batch classifier loss: 0.418474; batch adversarial loss: 0.565644
# epoch 86; iter: 0; batch classifier loss: 0.451706; batch adversarial loss: 0.599169
# epoch 87; iter: 0; batch classifier loss: 0.460894; batch adversarial loss: 0.615546
# epoch 88; iter: 0; batch classifier loss: 0.424773; batch adversarial loss: 0.546975
# epoch 89; iter: 0; batch classifier loss: 0.422465; batch adversarial loss: 0.581234
# epoch 90; iter: 0; batch classifier loss: 0.345614; batch adversarial loss: 0.601280
# epoch 91; iter: 0; batch classifier loss: 0.476795; batch adversarial loss: 0.544363
# epoch 92; iter: 0; batch classifier loss: 0.469045; batch adversarial loss: 0.556176
# epoch 93; iter: 0; batch classifier loss: 0.379647; batch adversarial loss: 0.608662
# epoch 94; iter: 0; batch classifier loss: 0.346700; batch adversarial loss: 0.590589
# epoch 95; iter: 0; batch classifier loss: 0.411423; batch adversarial loss: 0.610542
# epoch 96; iter: 0; batch classifier loss: 0.368005; batch adversarial loss: 0.602269
# epoch 97; iter: 0; batch classifier loss: 0.415924; batch adversarial loss: 0.632575
# epoch 98; iter: 0; batch classifier loss: 0.437202; batch adversarial loss: 0.565477
# epoch 99; iter: 0; batch classifier loss: 0.362628; batch adversarial loss: 0.562912
# epoch 0; iter: 0; batch classifier loss: 0.733478; batch adversarial loss: 0.852247
# epoch 1; iter: 0; batch classifier loss: 0.706748; batch adversarial loss: 0.879423
# epoch 2; iter: 0; batch classifier loss: 0.725741; batch adversarial loss: 0.807076
# epoch 3; iter: 0; batch classifier loss: 0.657644; batch adversarial loss: 0.792498
# epoch 4; iter: 0; batch classifier loss: 0.576627; batch adversarial loss: 0.732116
# epoch 5; iter: 0; batch classifier loss: 0.554036; batch adversarial loss: 0.670027
# epoch 6; iter: 0; batch classifier loss: 0.503948; batch adversarial loss: 0.674452
# epoch 7; iter: 0; batch classifier loss: 0.518260; batch adversarial loss: 0.641855
# epoch 8; iter: 0; batch classifier loss: 0.581126; batch adversarial loss: 0.638246
# epoch 9; iter: 0; batch classifier loss: 0.522277; batch adversarial loss: 0.627047
# epoch 10; iter: 0; batch classifier loss: 0.477651; batch adversarial loss: 0.625891
# epoch 11; iter: 0; batch classifier loss: 0.466543; batch adversarial loss: 0.655004
# epoch 12; iter: 0; batch classifier loss: 0.494340; batch adversarial loss: 0.581759
# epoch 13; iter: 0; batch classifier loss: 0.512911; batch adversarial loss: 0.602628
# epoch 14; iter: 0; batch classifier loss: 0.523790; batch adversarial loss: 0.601251
# epoch 15; iter: 0; batch classifier loss: 0.525092; batch adversarial loss: 0.561560
# epoch 16; iter: 0; batch classifier loss: 0.492213; batch adversarial loss: 0.573964
# epoch 17; iter: 0; batch classifier loss: 0.477552; batch adversarial loss: 0.617308
# epoch 18; iter: 0; batch classifier loss: 0.494157; batch adversarial loss: 0.607957
# epoch 19; iter: 0; batch classifier loss: 0.487762; batch adversarial loss: 0.562093
# epoch 20; iter: 0; batch classifier loss: 0.491909; batch adversarial loss: 0.579886
# epoch 21; iter: 0; batch classifier loss: 0.490818; batch adversarial loss: 0.566084
# epoch 22; iter: 0; batch classifier loss: 0.502401; batch adversarial loss: 0.568577
# epoch 23; iter: 0; batch classifier loss: 0.580812; batch adversarial loss: 0.564656
# epoch 24; iter: 0; batch classifier loss: 0.422112; batch adversarial loss: 0.532330
# epoch 25; iter: 0; batch classifier loss: 0.425253; batch adversarial loss: 0.603253
# epoch 26; iter: 0; batch classifier loss: 0.464358; batch adversarial loss: 0.624501
# epoch 27; iter: 0; batch classifier loss: 0.448144; batch adversarial loss: 0.582044
# epoch 28; iter: 0; batch classifier loss: 0.490545; batch adversarial loss: 0.688738
# epoch 29; iter: 0; batch classifier loss: 0.540919; batch adversarial loss: 0.598837
# epoch 30; iter: 0; batch classifier loss: 0.493551; batch adversarial loss: 0.580117
# epoch 31; iter: 0; batch classifier loss: 0.502387; batch adversarial loss: 0.589989
# epoch 32; iter: 0; batch classifier loss: 0.506436; batch adversarial loss: 0.660646
# epoch 33; iter: 0; batch classifier loss: 0.475161; batch adversarial loss: 0.562201
# epoch 34; iter: 0; batch classifier loss: 0.454427; batch adversarial loss: 0.598647
# epoch 35; iter: 0; batch classifier loss: 0.471188; batch adversarial loss: 0.625771
# epoch 36; iter: 0; batch classifier loss: 0.498277; batch adversarial loss: 0.664009
# epoch 37; iter: 0; batch classifier loss: 0.526837; batch adversarial loss: 0.585760
# epoch 38; iter: 0; batch classifier loss: 0.423763; batch adversarial loss: 0.637537
# epoch 39; iter: 0; batch classifier loss: 0.446817; batch adversarial loss: 0.601359
# epoch 40; iter: 0; batch classifier loss: 0.397840; batch adversarial loss: 0.515384
# epoch 41; iter: 0; batch classifier loss: 0.404022; batch adversarial loss: 0.581220
# epoch 42; iter: 0; batch classifier loss: 0.459557; batch adversarial loss: 0.635592
# epoch 43; iter: 0; batch classifier loss: 0.468395; batch adversarial loss: 0.640389
# epoch 44; iter: 0; batch classifier loss: 0.497423; batch adversarial loss: 0.629291
# epoch 45; iter: 0; batch classifier loss: 0.453041; batch adversarial loss: 0.576782
# epoch 46; iter: 0; batch classifier loss: 0.404111; batch adversarial loss: 0.529016
# epoch 47; iter: 0; batch classifier loss: 0.434620; batch adversarial loss: 0.590727
# epoch 48; iter: 0; batch classifier loss: 0.448570; batch adversarial loss: 0.654945
# epoch 49; iter: 0; batch classifier loss: 0.469626; batch adversarial loss: 0.683837
# epoch 50; iter: 0; batch classifier loss: 0.405763; batch adversarial loss: 0.539293
# epoch 51; iter: 0; batch classifier loss: 0.501060; batch adversarial loss: 0.600040
# epoch 52; iter: 0; batch classifier loss: 0.518658; batch adversarial loss: 0.616883
# epoch 53; iter: 0; batch classifier loss: 0.635866; batch adversarial loss: 0.584224
# epoch 54; iter: 0; batch classifier loss: 0.412548; batch adversarial loss: 0.609177
# epoch 55; iter: 0; batch classifier loss: 0.381849; batch adversarial loss: 0.617980
# epoch 56; iter: 0; batch classifier loss: 0.319090; batch adversarial loss: 0.596363
# epoch 57; iter: 0; batch classifier loss: 0.394598; batch adversarial loss: 0.585929
# epoch 58; iter: 0; batch classifier loss: 0.418004; batch adversarial loss: 0.536480
# epoch 59; iter: 0; batch classifier loss: 0.311809; batch adversarial loss: 0.578707
# epoch 60; iter: 0; batch classifier loss: 0.363399; batch adversarial loss: 0.594225
# epoch 61; iter: 0; batch classifier loss: 0.391232; batch adversarial loss: 0.602265
# epoch 62; iter: 0; batch classifier loss: 0.390944; batch adversarial loss: 0.550322
# epoch 63; iter: 0; batch classifier loss: 0.388541; batch adversarial loss: 0.579309
# epoch 64; iter: 0; batch classifier loss: 0.375376; batch adversarial loss: 0.588517
# epoch 65; iter: 0; batch classifier loss: 0.302271; batch adversarial loss: 0.559387
# epoch 66; iter: 0; batch classifier loss: 0.360701; batch adversarial loss: 0.494174
# epoch 67; iter: 0; batch classifier loss: 0.380619; batch adversarial loss: 0.556253
# epoch 68; iter: 0; batch classifier loss: 0.299118; batch adversarial loss: 0.590050
# epoch 69; iter: 0; batch classifier loss: 0.349280; batch adversarial loss: 0.617530
# epoch 70; iter: 0; batch classifier loss: 0.331497; batch adversarial loss: 0.515793
# epoch 71; iter: 0; batch classifier loss: 0.349505; batch adversarial loss: 0.603047
# epoch 72; iter: 0; batch classifier loss: 0.288828; batch adversarial loss: 0.509425
# epoch 73; iter: 0; batch classifier loss: 0.347012; batch adversarial loss: 0.581778
# epoch 74; iter: 0; batch classifier loss: 0.280756; batch adversarial loss: 0.605663
# epoch 75; iter: 0; batch classifier loss: 0.294718; batch adversarial loss: 0.572005
# epoch 76; iter: 0; batch classifier loss: 0.330666; batch adversarial loss: 0.518258
# epoch 77; iter: 0; batch classifier loss: 0.362532; batch adversarial loss: 0.588652
# epoch 78; iter: 0; batch classifier loss: 0.341900; batch adversarial loss: 0.568952
# epoch 79; iter: 0; batch classifier loss: 0.311026; batch adversarial loss: 0.581964
# epoch 80; iter: 0; batch classifier loss: 0.284976; batch adversarial loss: 0.605324
# epoch 81; iter: 0; batch classifier loss: 0.278524; batch adversarial loss: 0.583761
# epoch 82; iter: 0; batch classifier loss: 0.337237; batch adversarial loss: 0.622377
# epoch 83; iter: 0; batch classifier loss: 0.314489; batch adversarial loss: 0.558870
# epoch 84; iter: 0; batch classifier loss: 0.345188; batch adversarial loss: 0.557890
# epoch 85; iter: 0; batch classifier loss: 0.314515; batch adversarial loss: 0.559658
# epoch 86; iter: 0; batch classifier loss: 0.354012; batch adversarial loss: 0.601711
# epoch 87; iter: 0; batch classifier loss: 0.350350; batch adversarial loss: 0.617966
# epoch 88; iter: 0; batch classifier loss: 0.305497; batch adversarial loss: 0.542244
# epoch 89; iter: 0; batch classifier loss: 0.319959; batch adversarial loss: 0.577255
# epoch 90; iter: 0; batch classifier loss: 0.283581; batch adversarial loss: 0.602962
# epoch 91; iter: 0; batch classifier loss: 0.358907; batch adversarial loss: 0.539443
# epoch 92; iter: 0; batch classifier loss: 0.361461; batch adversarial loss: 0.554160
# epoch 93; iter: 0; batch classifier loss: 0.312035; batch adversarial loss: 0.603366
# epoch 94; iter: 0; batch classifier loss: 0.291033; batch adversarial loss: 0.591747
# epoch 95; iter: 0; batch classifier loss: 0.325720; batch adversarial loss: 0.606450
# epoch 96; iter: 0; batch classifier loss: 0.234820; batch adversarial loss: 0.600043
# epoch 97; iter: 0; batch classifier loss: 0.248562; batch adversarial loss: 0.633220
# epoch 98; iter: 0; batch classifier loss: 0.320048; batch adversarial loss: 0.559259
# epoch 99; iter: 0; batch classifier loss: 0.277342; batch adversarial loss: 0.560203
# epoch 100; iter: 0; batch classifier loss: 0.286723; batch adversarial loss: 0.519088
# epoch 101; iter: 0; batch classifier loss: 0.309663; batch adversarial loss: 0.524857
# epoch 102; iter: 0; batch classifier loss: 0.321426; batch adversarial loss: 0.608002
# epoch 103; iter: 0; batch classifier loss: 0.304650; batch adversarial loss: 0.619051
# epoch 104; iter: 0; batch classifier loss: 0.348157; batch adversarial loss: 0.601662
# epoch 105; iter: 0; batch classifier loss: 0.263831; batch adversarial loss: 0.626320
# epoch 106; iter: 0; batch classifier loss: 0.320437; batch adversarial loss: 0.618328
# epoch 107; iter: 0; batch classifier loss: 0.290100; batch adversarial loss: 0.520663
# epoch 108; iter: 0; batch classifier loss: 0.320204; batch adversarial loss: 0.584188
# epoch 109; iter: 0; batch classifier loss: 0.322058; batch adversarial loss: 0.534032
# epoch 110; iter: 0; batch classifier loss: 0.298852; batch adversarial loss: 0.581024
# epoch 111; iter: 0; batch classifier loss: 0.245120; batch adversarial loss: 0.586905
# epoch 112; iter: 0; batch classifier loss: 0.288981; batch adversarial loss: 0.508864
# epoch 113; iter: 0; batch classifier loss: 0.253314; batch adversarial loss: 0.620676
# epoch 114; iter: 0; batch classifier loss: 0.260857; batch adversarial loss: 0.676939
# epoch 115; iter: 0; batch classifier loss: 0.237311; batch adversarial loss: 0.575945
# epoch 116; iter: 0; batch classifier loss: 0.279974; batch adversarial loss: 0.622321
# epoch 117; iter: 0; batch classifier loss: 0.258933; batch adversarial loss: 0.583818
# epoch 118; iter: 0; batch classifier loss: 0.340395; batch adversarial loss: 0.604815
# epoch 119; iter: 0; batch classifier loss: 0.308407; batch adversarial loss: 0.545523
# epoch 120; iter: 0; batch classifier loss: 0.335860; batch adversarial loss: 0.650604
# epoch 121; iter: 0; batch classifier loss: 0.310744; batch adversarial loss: 0.596365
# epoch 122; iter: 0; batch classifier loss: 0.304568; batch adversarial loss: 0.606857
# epoch 123; iter: 0; batch classifier loss: 0.362257; batch adversarial loss: 0.607102
# epoch 124; iter: 0; batch classifier loss: 0.302435; batch adversarial loss: 0.572149
# epoch 125; iter: 0; batch classifier loss: 0.299001; batch adversarial loss: 0.592312
# epoch 126; iter: 0; batch classifier loss: 0.452778; batch adversarial loss: 0.596125
# epoch 127; iter: 0; batch classifier loss: 0.361041; batch adversarial loss: 0.617947
# epoch 128; iter: 0; batch classifier loss: 0.332597; batch adversarial loss: 0.570803
# epoch 129; iter: 0; batch classifier loss: 0.310803; batch adversarial loss: 0.622337
# epoch 130; iter: 0; batch classifier loss: 0.279610; batch adversarial loss: 0.498634
# epoch 131; iter: 0; batch classifier loss: 0.295233; batch adversarial loss: 0.560395
# epoch 132; iter: 0; batch classifier loss: 0.340346; batch adversarial loss: 0.544050
# epoch 133; iter: 0; batch classifier loss: 0.318600; batch adversarial loss: 0.563646
# epoch 134; iter: 0; batch classifier loss: 0.270515; batch adversarial loss: 0.557838
# epoch 135; iter: 0; batch classifier loss: 0.292497; batch adversarial loss: 0.586405
# epoch 136; iter: 0; batch classifier loss: 0.280516; batch adversarial loss: 0.606671
# epoch 137; iter: 0; batch classifier loss: 0.266872; batch adversarial loss: 0.605190
# epoch 138; iter: 0; batch classifier loss: 0.240535; batch adversarial loss: 0.561459
# epoch 139; iter: 0; batch classifier loss: 0.379443; batch adversarial loss: 0.528050
# epoch 140; iter: 0; batch classifier loss: 0.296806; batch adversarial loss: 0.631208
# epoch 141; iter: 0; batch classifier loss: 0.255670; batch adversarial loss: 0.549519
# epoch 142; iter: 0; batch classifier loss: 0.213998; batch adversarial loss: 0.643451
# epoch 143; iter: 0; batch classifier loss: 0.286536; batch adversarial loss: 0.580724
# epoch 144; iter: 0; batch classifier loss: 0.375814; batch adversarial loss: 0.539416
# epoch 145; iter: 0; batch classifier loss: 0.388345; batch adversarial loss: 0.571750
# epoch 146; iter: 0; batch classifier loss: 0.287361; batch adversarial loss: 0.680593
# epoch 147; iter: 0; batch classifier loss: 0.313894; batch adversarial loss: 0.551910
# epoch 148; iter: 0; batch classifier loss: 0.290398; batch adversarial loss: 0.584943
# epoch 149; iter: 0; batch classifier loss: 0.292064; batch adversarial loss: 0.521237
# epoch 150; iter: 0; batch classifier loss: 0.252743; batch adversarial loss: 0.560573
# epoch 151; iter: 0; batch classifier loss: 0.361139; batch adversarial loss: 0.566204
# epoch 152; iter: 0; batch classifier loss: 0.330764; batch adversarial loss: 0.606978
# epoch 153; iter: 0; batch classifier loss: 0.292425; batch adversarial loss: 0.574035
# epoch 154; iter: 0; batch classifier loss: 0.329805; batch adversarial loss: 0.549356
# epoch 155; iter: 0; batch classifier loss: 0.267165; batch adversarial loss: 0.591385
# epoch 156; iter: 0; batch classifier loss: 0.392358; batch adversarial loss: 0.555996
# epoch 157; iter: 0; batch classifier loss: 0.312598; batch adversarial loss: 0.592845
# epoch 158; iter: 0; batch classifier loss: 0.324133; batch adversarial loss: 0.589322
# epoch 159; iter: 0; batch classifier loss: 0.259357; batch adversarial loss: 0.570007
# epoch 160; iter: 0; batch classifier loss: 0.328683; batch adversarial loss: 0.575463
# epoch 161; iter: 0; batch classifier loss: 0.379227; batch adversarial loss: 0.582028
# epoch 162; iter: 0; batch classifier loss: 0.333431; batch adversarial loss: 0.562026
# epoch 163; iter: 0; batch classifier loss: 0.301270; batch adversarial loss: 0.586376
# epoch 164; iter: 0; batch classifier loss: 0.477090; batch adversarial loss: 0.547954
# epoch 165; iter: 0; batch classifier loss: 0.250532; batch adversarial loss: 0.616561
# epoch 166; iter: 0; batch classifier loss: 0.309050; batch adversarial loss: 0.601702
# epoch 167; iter: 0; batch classifier loss: 0.290813; batch adversarial loss: 0.597385
# epoch 168; iter: 0; batch classifier loss: 0.398407; batch adversarial loss: 0.671590
# epoch 169; iter: 0; batch classifier loss: 0.236831; batch adversarial loss: 0.557573
# epoch 170; iter: 0; batch classifier loss: 0.303511; batch adversarial loss: 0.571848
# epoch 171; iter: 0; batch classifier loss: 0.346731; batch adversarial loss: 0.628913
# epoch 172; iter: 0; batch classifier loss: 0.244765; batch adversarial loss: 0.575361
# epoch 173; iter: 0; batch classifier loss: 0.327942; batch adversarial loss: 0.626904
# epoch 174; iter: 0; batch classifier loss: 0.414355; batch adversarial loss: 0.623515
# epoch 175; iter: 0; batch classifier loss: 0.279142; batch adversarial loss: 0.579997
# epoch 176; iter: 0; batch classifier loss: 0.269638; batch adversarial loss: 0.613544
# epoch 177; iter: 0; batch classifier loss: 0.256123; batch adversarial loss: 0.602176
# epoch 178; iter: 0; batch classifier loss: 0.308921; batch adversarial loss: 0.595285
# epoch 179; iter: 0; batch classifier loss: 0.348540; batch adversarial loss: 0.574871
# epoch 180; iter: 0; batch classifier loss: 0.345729; batch adversarial loss: 0.538124
# epoch 181; iter: 0; batch classifier loss: 0.285504; batch adversarial loss: 0.518562
# epoch 182; iter: 0; batch classifier loss: 0.279432; batch adversarial loss: 0.619782
# epoch 183; iter: 0; batch classifier loss: 0.402511; batch adversarial loss: 0.492583
# epoch 184; iter: 0; batch classifier loss: 0.327929; batch adversarial loss: 0.536731
# epoch 185; iter: 0; batch classifier loss: 0.397211; batch adversarial loss: 0.564152
# epoch 186; iter: 0; batch classifier loss: 0.316964; batch adversarial loss: 0.590603
# epoch 187; iter: 0; batch classifier loss: 0.366016; batch adversarial loss: 0.586131
# epoch 188; iter: 0; batch classifier loss: 0.309388; batch adversarial loss: 0.612546
# epoch 189; iter: 0; batch classifier loss: 0.281401; batch adversarial loss: 0.659517
# epoch 190; iter: 0; batch classifier loss: 0.305277; batch adversarial loss: 0.579284
# epoch 191; iter: 0; batch classifier loss: 0.240739; batch adversarial loss: 0.724131
# epoch 192; iter: 0; batch classifier loss: 0.299613; batch adversarial loss: 0.593558
# epoch 193; iter: 0; batch classifier loss: 0.317528; batch adversarial loss: 0.610767
# epoch 194; iter: 0; batch classifier loss: 0.296910; batch adversarial loss: 0.635694
# epoch 195; iter: 0; batch classifier loss: 0.360130; batch adversarial loss: 0.534179
# epoch 196; iter: 0; batch classifier loss: 0.310333; batch adversarial loss: 0.528127
# epoch 197; iter: 0; batch classifier loss: 0.428896; batch adversarial loss: 0.470048
# epoch 198; iter: 0; batch classifier loss: 0.248349; batch adversarial loss: 0.599640
# epoch 199; iter: 0; batch classifier loss: 0.360862; batch adversarial loss: 0.580209
# epoch 0; iter: 0; batch classifier loss: 0.782897; batch adversarial loss: 0.861270
# epoch 1; iter: 0; batch classifier loss: 0.630554; batch adversarial loss: 0.810883
# epoch 2; iter: 0; batch classifier loss: 0.605811; batch adversarial loss: 0.754761
# epoch 3; iter: 0; batch classifier loss: 0.595023; batch adversarial loss: 0.718922
# epoch 4; iter: 0; batch classifier loss: 0.524569; batch adversarial loss: 0.694100
# epoch 5; iter: 0; batch classifier loss: 0.520563; batch adversarial loss: 0.660261
# epoch 6; iter: 0; batch classifier loss: 0.504765; batch adversarial loss: 0.670658
# epoch 7; iter: 0; batch classifier loss: 0.528367; batch adversarial loss: 0.638700
# epoch 8; iter: 0; batch classifier loss: 0.597415; batch adversarial loss: 0.640704
# epoch 9; iter: 0; batch classifier loss: 0.544742; batch adversarial loss: 0.624193
# epoch 10; iter: 0; batch classifier loss: 0.478274; batch adversarial loss: 0.629977
# epoch 11; iter: 0; batch classifier loss: 0.471580; batch adversarial loss: 0.654827
# epoch 12; iter: 0; batch classifier loss: 0.519743; batch adversarial loss: 0.580177
# epoch 13; iter: 0; batch classifier loss: 0.518510; batch adversarial loss: 0.602944
# epoch 14; iter: 0; batch classifier loss: 0.515328; batch adversarial loss: 0.603346
# epoch 15; iter: 0; batch classifier loss: 0.528619; batch adversarial loss: 0.555179
# epoch 16; iter: 0; batch classifier loss: 0.530056; batch adversarial loss: 0.558790
# epoch 17; iter: 0; batch classifier loss: 0.525882; batch adversarial loss: 0.592400
# epoch 18; iter: 0; batch classifier loss: 0.538751; batch adversarial loss: 0.580593
# epoch 19; iter: 0; batch classifier loss: 0.501149; batch adversarial loss: 0.530142
# epoch 20; iter: 0; batch classifier loss: 0.485469; batch adversarial loss: 0.556784
# epoch 21; iter: 0; batch classifier loss: 0.493692; batch adversarial loss: 0.541098
# epoch 22; iter: 0; batch classifier loss: 0.543481; batch adversarial loss: 0.550191
# epoch 23; iter: 0; batch classifier loss: 0.597227; batch adversarial loss: 0.543444
# epoch 24; iter: 0; batch classifier loss: 0.447498; batch adversarial loss: 0.514521
# epoch 25; iter: 0; batch classifier loss: 0.463744; batch adversarial loss: 0.577493
# epoch 26; iter: 0; batch classifier loss: 0.487527; batch adversarial loss: 0.582342
# epoch 27; iter: 0; batch classifier loss: 0.450966; batch adversarial loss: 0.540935
# epoch 28; iter: 0; batch classifier loss: 0.432226; batch adversarial loss: 0.601667
# epoch 29; iter: 0; batch classifier loss: 0.513953; batch adversarial loss: 0.510899
# epoch 30; iter: 0; batch classifier loss: 0.479864; batch adversarial loss: 0.510739
# epoch 31; iter: 0; batch classifier loss: 0.463321; batch adversarial loss: 0.535210
# epoch 32; iter: 0; batch classifier loss: 0.467924; batch adversarial loss: 0.618456
# epoch 33; iter: 0; batch classifier loss: 0.515525; batch adversarial loss: 0.558336
# epoch 34; iter: 0; batch classifier loss: 0.471303; batch adversarial loss: 0.595879
# epoch 35; iter: 0; batch classifier loss: 0.486914; batch adversarial loss: 0.662561
# epoch 36; iter: 0; batch classifier loss: 0.539646; batch adversarial loss: 0.689425
# epoch 37; iter: 0; batch classifier loss: 0.572001; batch adversarial loss: 0.612035
# epoch 38; iter: 0; batch classifier loss: 0.439921; batch adversarial loss: 0.644823
# epoch 39; iter: 0; batch classifier loss: 0.551611; batch adversarial loss: 0.623198
# epoch 40; iter: 0; batch classifier loss: 0.458100; batch adversarial loss: 0.514550
# epoch 41; iter: 0; batch classifier loss: 0.519100; batch adversarial loss: 0.593621
# epoch 42; iter: 0; batch classifier loss: 0.515154; batch adversarial loss: 0.662576
# epoch 43; iter: 0; batch classifier loss: 0.540486; batch adversarial loss: 0.657535
# epoch 44; iter: 0; batch classifier loss: 0.572356; batch adversarial loss: 0.653790
# epoch 45; iter: 0; batch classifier loss: 0.498507; batch adversarial loss: 0.582545
# epoch 46; iter: 0; batch classifier loss: 0.478819; batch adversarial loss: 0.543955
# epoch 47; iter: 0; batch classifier loss: 0.508473; batch adversarial loss: 0.599611
# epoch 48; iter: 0; batch classifier loss: 0.478209; batch adversarial loss: 0.661010
# epoch 49; iter: 0; batch classifier loss: 0.495857; batch adversarial loss: 0.695342
# epoch 50; iter: 0; batch classifier loss: 0.456599; batch adversarial loss: 0.543681
# epoch 51; iter: 0; batch classifier loss: 0.502737; batch adversarial loss: 0.611648
# epoch 52; iter: 0; batch classifier loss: 0.477530; batch adversarial loss: 0.630062
# epoch 53; iter: 0; batch classifier loss: 0.642908; batch adversarial loss: 0.604709
# epoch 54; iter: 0; batch classifier loss: 0.516687; batch adversarial loss: 0.633265
# epoch 55; iter: 0; batch classifier loss: 0.571856; batch adversarial loss: 0.637016
# epoch 56; iter: 0; batch classifier loss: 0.546196; batch adversarial loss: 0.612705
# epoch 57; iter: 0; batch classifier loss: 0.601887; batch adversarial loss: 0.595909
# epoch 58; iter: 0; batch classifier loss: 0.592376; batch adversarial loss: 0.544731
# epoch 59; iter: 0; batch classifier loss: 0.392503; batch adversarial loss: 0.581224
# epoch 60; iter: 0; batch classifier loss: 0.451247; batch adversarial loss: 0.595692
# epoch 61; iter: 0; batch classifier loss: 0.445725; batch adversarial loss: 0.601420
# epoch 62; iter: 0; batch classifier loss: 0.445737; batch adversarial loss: 0.553153
# epoch 63; iter: 0; batch classifier loss: 0.460785; batch adversarial loss: 0.579128
# epoch 64; iter: 0; batch classifier loss: 0.440040; batch adversarial loss: 0.588024
# epoch 65; iter: 0; batch classifier loss: 0.397264; batch adversarial loss: 0.559731
# epoch 66; iter: 0; batch classifier loss: 0.338231; batch adversarial loss: 0.491740
# epoch 67; iter: 0; batch classifier loss: 0.459167; batch adversarial loss: 0.557989
# epoch 68; iter: 0; batch classifier loss: 0.321701; batch adversarial loss: 0.585099
# epoch 69; iter: 0; batch classifier loss: 0.382108; batch adversarial loss: 0.614670
# epoch 70; iter: 0; batch classifier loss: 0.414607; batch adversarial loss: 0.513676
# epoch 71; iter: 0; batch classifier loss: 0.350624; batch adversarial loss: 0.597769
# epoch 72; iter: 0; batch classifier loss: 0.326987; batch adversarial loss: 0.504548
# epoch 73; iter: 0; batch classifier loss: 0.360676; batch adversarial loss: 0.574031
# epoch 74; iter: 0; batch classifier loss: 0.375927; batch adversarial loss: 0.599888
# epoch 75; iter: 0; batch classifier loss: 0.367226; batch adversarial loss: 0.567143
# epoch 76; iter: 0; batch classifier loss: 0.381728; batch adversarial loss: 0.512675
# epoch 77; iter: 0; batch classifier loss: 0.377341; batch adversarial loss: 0.582100
# epoch 78; iter: 0; batch classifier loss: 0.377679; batch adversarial loss: 0.565694
# epoch 79; iter: 0; batch classifier loss: 0.377523; batch adversarial loss: 0.579915
# epoch 80; iter: 0; batch classifier loss: 0.365335; batch adversarial loss: 0.597552
# epoch 81; iter: 0; batch classifier loss: 0.361299; batch adversarial loss: 0.580663
# epoch 82; iter: 0; batch classifier loss: 0.325028; batch adversarial loss: 0.620538
# epoch 83; iter: 0; batch classifier loss: 0.386986; batch adversarial loss: 0.561464
# epoch 84; iter: 0; batch classifier loss: 0.456113; batch adversarial loss: 0.552438
# epoch 85; iter: 0; batch classifier loss: 0.343272; batch adversarial loss: 0.554184
# epoch 86; iter: 0; batch classifier loss: 0.347073; batch adversarial loss: 0.586429
# epoch 87; iter: 0; batch classifier loss: 0.397808; batch adversarial loss: 0.611113
# epoch 88; iter: 0; batch classifier loss: 0.357608; batch adversarial loss: 0.538620
# epoch 89; iter: 0; batch classifier loss: 0.360969; batch adversarial loss: 0.564503
# epoch 90; iter: 0; batch classifier loss: 0.303304; batch adversarial loss: 0.598178
# epoch 91; iter: 0; batch classifier loss: 0.395646; batch adversarial loss: 0.531862
# epoch 92; iter: 0; batch classifier loss: 0.441459; batch adversarial loss: 0.548996
# epoch 93; iter: 0; batch classifier loss: 0.302544; batch adversarial loss: 0.594629
# epoch 94; iter: 0; batch classifier loss: 0.329145; batch adversarial loss: 0.590309
# epoch 95; iter: 0; batch classifier loss: 0.339579; batch adversarial loss: 0.595109
# epoch 96; iter: 0; batch classifier loss: 0.277786; batch adversarial loss: 0.588713
# epoch 97; iter: 0; batch classifier loss: 0.355125; batch adversarial loss: 0.626898
# epoch 98; iter: 0; batch classifier loss: 0.378991; batch adversarial loss: 0.557616
# epoch 99; iter: 0; batch classifier loss: 0.346678; batch adversarial loss: 0.555324
# epoch 100; iter: 0; batch classifier loss: 0.334397; batch adversarial loss: 0.523686
# epoch 101; iter: 0; batch classifier loss: 0.337264; batch adversarial loss: 0.515321
# epoch 102; iter: 0; batch classifier loss: 0.385048; batch adversarial loss: 0.609748
# epoch 103; iter: 0; batch classifier loss: 0.326960; batch adversarial loss: 0.619202
# epoch 104; iter: 0; batch classifier loss: 0.376210; batch adversarial loss: 0.605749
# epoch 105; iter: 0; batch classifier loss: 0.353275; batch adversarial loss: 0.626547
# epoch 106; iter: 0; batch classifier loss: 0.280747; batch adversarial loss: 0.608332
# epoch 107; iter: 0; batch classifier loss: 0.321465; batch adversarial loss: 0.508902
# epoch 108; iter: 0; batch classifier loss: 0.351686; batch adversarial loss: 0.575895
# epoch 109; iter: 0; batch classifier loss: 0.387902; batch adversarial loss: 0.528367
# epoch 110; iter: 0; batch classifier loss: 0.290745; batch adversarial loss: 0.566765
# epoch 111; iter: 0; batch classifier loss: 0.346527; batch adversarial loss: 0.586037
# epoch 112; iter: 0; batch classifier loss: 0.343828; batch adversarial loss: 0.503776
# epoch 113; iter: 0; batch classifier loss: 0.355626; batch adversarial loss: 0.609057
# epoch 114; iter: 0; batch classifier loss: 0.302227; batch adversarial loss: 0.675131
# epoch 115; iter: 0; batch classifier loss: 0.321794; batch adversarial loss: 0.573370
# epoch 116; iter: 0; batch classifier loss: 0.337245; batch adversarial loss: 0.615561
# epoch 117; iter: 0; batch classifier loss: 0.372736; batch adversarial loss: 0.584165
# epoch 118; iter: 0; batch classifier loss: 0.348948; batch adversarial loss: 0.584696
# epoch 119; iter: 0; batch classifier loss: 0.368597; batch adversarial loss: 0.530436
# epoch 120; iter: 0; batch classifier loss: 0.315265; batch adversarial loss: 0.641604
# epoch 121; iter: 0; batch classifier loss: 0.317671; batch adversarial loss: 0.586685
# epoch 122; iter: 0; batch classifier loss: 0.408000; batch adversarial loss: 0.602928
# epoch 123; iter: 0; batch classifier loss: 0.300672; batch adversarial loss: 0.603166
# epoch 124; iter: 0; batch classifier loss: 0.388177; batch adversarial loss: 0.565408
# epoch 125; iter: 0; batch classifier loss: 0.344455; batch adversarial loss: 0.577734
# epoch 126; iter: 0; batch classifier loss: 0.464274; batch adversarial loss: 0.582575
# epoch 127; iter: 0; batch classifier loss: 0.356541; batch adversarial loss: 0.603180
# epoch 128; iter: 0; batch classifier loss: 0.353067; batch adversarial loss: 0.552583
# epoch 129; iter: 0; batch classifier loss: 0.300215; batch adversarial loss: 0.626613
# epoch 130; iter: 0; batch classifier loss: 0.298198; batch adversarial loss: 0.487559
# epoch 131; iter: 0; batch classifier loss: 0.325139; batch adversarial loss: 0.559060
# epoch 132; iter: 0; batch classifier loss: 0.336457; batch adversarial loss: 0.535143
# epoch 133; iter: 0; batch classifier loss: 0.380000; batch adversarial loss: 0.555877
# epoch 134; iter: 0; batch classifier loss: 0.321368; batch adversarial loss: 0.551216
# epoch 135; iter: 0; batch classifier loss: 0.292443; batch adversarial loss: 0.575708
# epoch 136; iter: 0; batch classifier loss: 0.266590; batch adversarial loss: 0.595205
# epoch 137; iter: 0; batch classifier loss: 0.328033; batch adversarial loss: 0.606794
# epoch 138; iter: 0; batch classifier loss: 0.256512; batch adversarial loss: 0.565591
# epoch 139; iter: 0; batch classifier loss: 0.395574; batch adversarial loss: 0.516708
# epoch 140; iter: 0; batch classifier loss: 0.268289; batch adversarial loss: 0.610522
# epoch 141; iter: 0; batch classifier loss: 0.269061; batch adversarial loss: 0.545770
# epoch 142; iter: 0; batch classifier loss: 0.284487; batch adversarial loss: 0.635909
# epoch 143; iter: 0; batch classifier loss: 0.265781; batch adversarial loss: 0.573910
# epoch 144; iter: 0; batch classifier loss: 0.370391; batch adversarial loss: 0.529625
# epoch 145; iter: 0; batch classifier loss: 0.352599; batch adversarial loss: 0.567176
# epoch 146; iter: 0; batch classifier loss: 0.321943; batch adversarial loss: 0.690139
# epoch 147; iter: 0; batch classifier loss: 0.354476; batch adversarial loss: 0.547434
# epoch 148; iter: 0; batch classifier loss: 0.289395; batch adversarial loss: 0.572559
# epoch 149; iter: 0; batch classifier loss: 0.294268; batch adversarial loss: 0.514259
# epoch 150; iter: 0; batch classifier loss: 0.291874; batch adversarial loss: 0.549644
# epoch 151; iter: 0; batch classifier loss: 0.358827; batch adversarial loss: 0.559536
# epoch 152; iter: 0; batch classifier loss: 0.333356; batch adversarial loss: 0.587056
# epoch 153; iter: 0; batch classifier loss: 0.334665; batch adversarial loss: 0.573025
# epoch 154; iter: 0; batch classifier loss: 0.336412; batch adversarial loss: 0.535786
# epoch 155; iter: 0; batch classifier loss: 0.309754; batch adversarial loss: 0.588328
# ...
# epoch 37; iter: 0; batch classifier loss: 0.521950; batch adversarial loss: 0.488737
# epoch 38; iter: 0; batch classifier loss: 0.566748; batch adversarial loss: 0.461206
# epoch 39; iter: 0; batch classifier loss: 0.522328; batch adversarial loss: 0.500981
# epoch 40; iter: 0; batch classifier loss: 0.538273; batch adversarial loss: 0.465292
# epoch 41; iter: 0; batch classifier loss: 0.527215; batch adversarial loss: 0.441308
# epoch 42; iter: 0; batch classifier loss: 0.474994; batch adversarial loss: 0.445206
# epoch 43; iter: 0; batch classifier loss: 0.537730; batch adversarial loss: 0.443789
# epoch 44; iter: 0; batch classifier loss: 0.540481; batch adversarial loss: 0.453018
# epoch 45; iter: 0; batch classifier loss: 0.601634; batch adversarial loss: 0.481774
# epoch 46; iter: 0; batch classifier loss: 0.583168; batch adversarial loss: 0.526544
# epoch 47; iter: 0; batch classifier loss: 0.569554; batch adversarial loss: 0.468843
# epoch 48; iter: 0; batch classifier loss: 0.644714; batch adversarial loss: 0.514478
# epoch 49; iter: 0; batch classifier loss: 0.571203; batch adversarial loss: 0.480408
# epoch 50; iter: 0; batch classifier loss: 0.589764; batch adversarial loss: 0.437748
# epoch 51; iter: 0; batch classifier loss: 0.544260; batch adversarial loss: 0.505340
# epoch 52; iter: 0; batch classifier loss: 0.498282; batch adversarial loss: 0.474216
# epoch 53; iter: 0; batch classifier loss: 0.417753; batch adversarial loss: 0.513555
# epoch 54; iter: 0; batch classifier loss: 0.494835; batch adversarial loss: 0.462274
# epoch 55; iter: 0; batch classifier loss: 0.517679; batch adversarial loss: 0.552852
# epoch 56; iter: 0; batch classifier loss: 0.484071; batch adversarial loss: 0.469538
# epoch 57; iter: 0; batch classifier loss: 0.494482; batch adversarial loss: 0.533522
# epoch 58; iter: 0; batch classifier loss: 0.520914; batch adversarial loss: 0.504743
# epoch 59; iter: 0; batch classifier loss: 0.484671; batch adversarial loss: 0.431332
# epoch 60; iter: 0; batch classifier loss: 0.508060; batch adversarial loss: 0.393842
# epoch 61; iter: 0; batch classifier loss: 0.469079; batch adversarial loss: 0.461438
# epoch 62; iter: 0; batch classifier loss: 0.461897; batch adversarial loss: 0.508122
# epoch 63; iter: 0; batch classifier loss: 0.456396; batch adversarial loss: 0.512637
# epoch 64; iter: 0; batch classifier loss: 0.475905; batch adversarial loss: 0.502663
# epoch 65; iter: 0; batch classifier loss: 0.499541; batch adversarial loss: 0.464980
# epoch 66; iter: 0; batch classifier loss: 0.468595; batch adversarial loss: 0.488229
# epoch 67; iter: 0; batch classifier loss: 0.471535; batch adversarial loss: 0.526705
# epoch 68; iter: 0; batch classifier loss: 0.460113; batch adversarial loss: 0.442945
# epoch 69; iter: 0; batch classifier loss: 0.489037; batch adversarial loss: 0.583730
# epoch 70; iter: 0; batch classifier loss: 0.477874; batch adversarial loss: 0.442276
# epoch 71; iter: 0; batch classifier loss: 0.421150; batch adversarial loss: 0.445188
# epoch 72; iter: 0; batch classifier loss: 0.516469; batch adversarial loss: 0.445122
# epoch 73; iter: 0; batch classifier loss: 0.428996; batch adversarial loss: 0.465908
# epoch 74; iter: 0; batch classifier loss: 0.412637; batch adversarial loss: 0.472437
# epoch 75; iter: 0; batch classifier loss: 0.389485; batch adversarial loss: 0.520793
# epoch 76; iter: 0; batch classifier loss: 0.417810; batch adversarial loss: 0.405407
# epoch 77; iter: 0; batch classifier loss: 0.451092; batch adversarial loss: 0.466509
# epoch 78; iter: 0; batch classifier loss: 0.402504; batch adversarial loss: 0.528856
# epoch 79; iter: 0; batch classifier loss: 0.447714; batch adversarial loss: 0.460276
# epoch 80; iter: 0; batch classifier loss: 0.443996; batch adversarial loss: 0.478864
# epoch 81; iter: 0; batch classifier loss: 0.446793; batch adversarial loss: 0.452442
# epoch 82; iter: 0; batch classifier loss: 0.459592; batch adversarial loss: 0.449637
# epoch 83; iter: 0; batch classifier loss: 0.505897; batch adversarial loss: 0.450951
# epoch 84; iter: 0; batch classifier loss: 0.438366; batch adversarial loss: 0.518487
# epoch 85; iter: 0; batch classifier loss: 0.398505; batch adversarial loss: 0.547648
# epoch 86; iter: 0; batch classifier loss: 0.446449; batch adversarial loss: 0.417160
# epoch 87; iter: 0; batch classifier loss: 0.556158; batch adversarial loss: 0.412320
# epoch 88; iter: 0; batch classifier loss: 0.417146; batch adversarial loss: 0.466959
# epoch 89; iter: 0; batch classifier loss: 0.475236; batch adversarial loss: 0.482035
# epoch 90; iter: 0; batch classifier loss: 0.420735; batch adversarial loss: 0.500154
# epoch 91; iter: 0; batch classifier loss: 0.434320; batch adversarial loss: 0.431619
# epoch 92; iter: 0; batch classifier loss: 0.406308; batch adversarial loss: 0.476790
# epoch 93; iter: 0; batch classifier loss: 0.406513; batch adversarial loss: 0.453210
# epoch 94; iter: 0; batch classifier loss: 0.477176; batch adversarial loss: 0.519942
# epoch 95; iter: 0; batch classifier loss: 0.361536; batch adversarial loss: 0.453070
# epoch 96; iter: 0; batch classifier loss: 0.503288; batch adversarial loss: 0.402036
# epoch 97; iter: 0; batch classifier loss: 0.427480; batch adversarial loss: 0.507713
# epoch 98; iter: 0; batch classifier loss: 0.442090; batch adversarial loss: 0.503035
# epoch 99; iter: 0; batch classifier loss: 0.395701; batch adversarial loss: 0.477360
# epoch 100; iter: 0; batch classifier loss: 0.368924; batch adversarial loss: 0.491892
# epoch 101; iter: 0; batch classifier loss: 0.433883; batch adversarial loss: 0.494099
# epoch 102; iter: 0; batch classifier loss: 0.436904; batch adversarial loss: 0.530707
# epoch 103; iter: 0; batch classifier loss: 0.363344; batch adversarial loss: 0.468444
# epoch 104; iter: 0; batch classifier loss: 0.372099; batch adversarial loss: 0.509831
# epoch 105; iter: 0; batch classifier loss: 0.441655; batch adversarial loss: 0.429449
# epoch 106; iter: 0; batch classifier loss: 0.385812; batch adversarial loss: 0.445784
# epoch 107; iter: 0; batch classifier loss: 0.387947; batch adversarial loss: 0.426464
# epoch 108; iter: 0; batch classifier loss: 0.369125; batch adversarial loss: 0.502930
# epoch 109; iter: 0; batch classifier loss: 0.351439; batch adversarial loss: 0.505644
# epoch 110; iter: 0; batch classifier loss: 0.368085; batch adversarial loss: 0.553644
# epoch 111; iter: 0; batch classifier loss: 0.355082; batch adversarial loss: 0.475873
# epoch 112; iter: 0; batch classifier loss: 0.384767; batch adversarial loss: 0.496034
# epoch 113; iter: 0; batch classifier loss: 0.356469; batch adversarial loss: 0.484754
# epoch 114; iter: 0; batch classifier loss: 0.377565; batch adversarial loss: 0.517571
# epoch 115; iter: 0; batch classifier loss: 0.372778; batch adversarial loss: 0.486154
# epoch 116; iter: 0; batch classifier loss: 0.451047; batch adversarial loss: 0.484148
# epoch 117; iter: 0; batch classifier loss: 0.328041; batch adversarial loss: 0.538520
# epoch 118; iter: 0; batch classifier loss: 0.400389; batch adversarial loss: 0.512641
# epoch 119; iter: 0; batch classifier loss: 0.401380; batch adversarial loss: 0.485753
# epoch 120; iter: 0; batch classifier loss: 0.327260; batch adversarial loss: 0.437135
# epoch 121; iter: 0; batch classifier loss: 0.387460; batch adversarial loss: 0.467233
# epoch 122; iter: 0; batch classifier loss: 0.400511; batch adversarial loss: 0.561476
# epoch 123; iter: 0; batch classifier loss: 0.425780; batch adversarial loss: 0.514474
# epoch 124; iter: 0; batch classifier loss: 0.393517; batch adversarial loss: 0.451981
# epoch 125; iter: 0; batch classifier loss: 0.402856; batch adversarial loss: 0.468308
# epoch 126; iter: 0; batch classifier loss: 0.416622; batch adversarial loss: 0.516516
# epoch 127; iter: 0; batch classifier loss: 0.410989; batch adversarial loss: 0.443438
# epoch 128; iter: 0; batch classifier loss: 0.391027; batch adversarial loss: 0.553377
# epoch 129; iter: 0; batch classifier loss: 0.470590; batch adversarial loss: 0.494282
# epoch 130; iter: 0; batch classifier loss: 0.390438; batch adversarial loss: 0.543389
# epoch 131; iter: 0; batch classifier loss: 0.428473; batch adversarial loss: 0.496918
# epoch 132; iter: 0; batch classifier loss: 0.370167; batch adversarial loss: 0.505535
# epoch 133; iter: 0; batch classifier loss: 0.344910; batch adversarial loss: 0.521525
# epoch 134; iter: 0; batch classifier loss: 0.428159; batch adversarial loss: 0.558380
# epoch 135; iter: 0; batch classifier loss: 0.355436; batch adversarial loss: 0.415363
# epoch 136; iter: 0; batch classifier loss: 0.375431; batch adversarial loss: 0.482587
# epoch 137; iter: 0; batch classifier loss: 0.363965; batch adversarial loss: 0.510039
# epoch 138; iter: 0; batch classifier loss: 0.390755; batch adversarial loss: 0.570386
# epoch 139; iter: 0; batch classifier loss: 0.399358; batch adversarial loss: 0.447724
# epoch 140; iter: 0; batch classifier loss: 0.444006; batch adversarial loss: 0.432845
# epoch 141; iter: 0; batch classifier loss: 0.421338; batch adversarial loss: 0.461459
# epoch 142; iter: 0; batch classifier loss: 0.330249; batch adversarial loss: 0.618029
# epoch 143; iter: 0; batch classifier loss: 0.406850; batch adversarial loss: 0.515617
# epoch 144; iter: 0; batch classifier loss: 0.446455; batch adversarial loss: 0.448335
# epoch 145; iter: 0; batch classifier loss: 0.425872; batch adversarial loss: 0.456896
# epoch 146; iter: 0; batch classifier loss: 0.469033; batch adversarial loss: 0.387254
# epoch 147; iter: 0; batch classifier loss: 0.414279; batch adversarial loss: 0.398680
# epoch 148; iter: 0; batch classifier loss: 0.370357; batch adversarial loss: 0.440367
# epoch 149; iter: 0; batch classifier loss: 0.363455; batch adversarial loss: 0.444516
# epoch 150; iter: 0; batch classifier loss: 0.451180; batch adversarial loss: 0.574478
# epoch 151; iter: 0; batch classifier loss: 0.344181; batch adversarial loss: 0.547287
# epoch 152; iter: 0; batch classifier loss: 0.349249; batch adversarial loss: 0.476662
# epoch 153; iter: 0; batch classifier loss: 0.376236; batch adversarial loss: 0.482226
# epoch 154; iter: 0; batch classifier loss: 0.384203; batch adversarial loss: 0.491862
# epoch 155; iter: 0; batch classifier loss: 0.354119; batch adversarial loss: 0.506995
# epoch 156; iter: 0; batch classifier loss: 0.472748; batch adversarial loss: 0.436412
# epoch 157; iter: 0; batch classifier loss: 0.375798; batch adversarial loss: 0.508213
# epoch 158; iter: 0; batch classifier loss: 0.397968; batch adversarial loss: 0.536338
# epoch 159; iter: 0; batch classifier loss: 0.327030; batch adversarial loss: 0.359640
# epoch 160; iter: 0; batch classifier loss: 0.396935; batch adversarial loss: 0.476440
# epoch 161; iter: 0; batch classifier loss: 0.441958; batch adversarial loss: 0.587014
# epoch 162; iter: 0; batch classifier loss: 0.369884; batch adversarial loss: 0.436970
# epoch 163; iter: 0; batch classifier loss: 0.429528; batch adversarial loss: 0.501558
# epoch 164; iter: 0; batch classifier loss: 0.482202; batch adversarial loss: 0.348031
# epoch 165; iter: 0; batch classifier loss: 0.409029; batch adversarial loss: 0.551245
# epoch 166; iter: 0; batch classifier loss: 0.418482; batch adversarial loss: 0.465563
# epoch 167; iter: 0; batch classifier loss: 0.471839; batch adversarial loss: 0.547436
# epoch 168; iter: 0; batch classifier loss: 0.331482; batch adversarial loss: 0.484419
# epoch 169; iter: 0; batch classifier loss: 0.431389; batch adversarial loss: 0.382734
# epoch 170; iter: 0; batch classifier loss: 0.346363; batch adversarial loss: 0.507772
# epoch 171; iter: 0; batch classifier loss: 0.329329; batch adversarial loss: 0.474854
# epoch 172; iter: 0; batch classifier loss: 0.389726; batch adversarial loss: 0.464580
# epoch 173; iter: 0; batch classifier loss: 0.515066; batch adversarial loss: 0.476025
# epoch 174; iter: 0; batch classifier loss: 0.410605; batch adversarial loss: 0.436836
# epoch 175; iter: 0; batch classifier loss: 0.458672; batch adversarial loss: 0.564969
# epoch 176; iter: 0; batch classifier loss: 0.362203; batch adversarial loss: 0.504540
# epoch 177; iter: 0; batch classifier loss: 0.402276; batch adversarial loss: 0.529850
# epoch 178; iter: 0; batch classifier loss: 0.353621; batch adversarial loss: 0.525870
# epoch 179; iter: 0; batch classifier loss: 0.415295; batch adversarial loss: 0.555916
# epoch 180; iter: 0; batch classifier loss: 0.354356; batch adversarial loss: 0.534990
# epoch 181; iter: 0; batch classifier loss: 0.378475; batch adversarial loss: 0.451557
# epoch 182; iter: 0; batch classifier loss: 0.332370; batch adversarial loss: 0.521257
# epoch 183; iter: 0; batch classifier loss: 0.382682; batch adversarial loss: 0.435926
# epoch 184; iter: 0; batch classifier loss: 0.403257; batch adversarial loss: 0.466301
# epoch 185; iter: 0; batch classifier loss: 0.425799; batch adversarial loss: 0.457690
# epoch 186; iter: 0; batch classifier loss: 0.312295; batch adversarial loss: 0.466656
# epoch 187; iter: 0; batch classifier loss: 0.367469; batch adversarial loss: 0.492354
# epoch 188; iter: 0; batch classifier loss: 0.320319; batch adversarial loss: 0.511660
# epoch 189; iter: 0; batch classifier loss: 0.343589; batch adversarial loss: 0.488894
# epoch 190; iter: 0; batch classifier loss: 0.380564; batch adversarial loss: 0.527871
# epoch 191; iter: 0; batch classifier loss: 0.349063; batch adversarial loss: 0.437671
# epoch 192; iter: 0; batch classifier loss: 0.366025; batch adversarial loss: 0.495030
# epoch 193; iter: 0; batch classifier loss: 0.435850; batch adversarial loss: 0.425549
# epoch 194; iter: 0; batch classifier loss: 0.400768; batch adversarial loss: 0.473512
# epoch 195; iter: 0; batch classifier loss: 0.301525; batch adversarial loss: 0.480071
# epoch 196; iter: 0; batch classifier loss: 0.340382; batch adversarial loss: 0.500816
# epoch 197; iter: 0; batch classifier loss: 0.416664; batch adversarial loss: 0.603358
# epoch 198; iter: 0; batch classifier loss: 0.396636; batch adversarial loss: 0.434930
# epoch 199; iter: 0; batch classifier loss: 0.345761; batch adversarial loss: 0.568561
# Probas: [[8.56597438e-01 1.43402562e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[9.99988337e-01 1.16631345e-05]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[5.25006235e-01 4.74993765e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[9.16599765e-01 8.34002346e-02]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[6.04970932e-01 3.95029068e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[8.48015413e-01 1.51984587e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[5.86969286e-01 4.13030714e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[8.65484044e-01 1.34515956e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[9.99980404e-01 1.95958601e-05]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]
# Probas: [[2.40318537e-01 7.59681463e-01]
#  [2.24184990e-03 9.97758150e-01]
#  [9.92843692e-01 7.15630781e-03]
#  [2.00845480e-01 7.99154520e-01]
#  [1.19268894e-04 9.99880731e-01]] Sums: [1. 1. 1. 1. 1.]

# %%
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'num_epochs': 200, 'classifier_num_hidden_units': 100, 'adversary_loss_weight': 0.7400695233211934}
# Medium - Parâmetros: {'num_epochs': 100, 'classifier_num_hidden_units': 100, 'adversary_loss_weight': 1.9982188470730742}
# Low - Parâmetros: {'num_epochs': 200, 'classifier_num_hidden_units': 100, 'adversary_loss_weight': 1.977880362237054}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Inprocessing: Adversarial Debiasing', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Inprocessing: Adversarial Debiasing', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Inprocessing: Adversarial Debiasing', privileged_group, unprivileged_group)

df_metrics_Adv = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics = pd.concat([df_metrics, df_metrics_Adv], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_in_adv_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# yearsOfEducation_Postgraduate Education                  0.232272
# age_Young Adult                                          0.229507
# case:protected                                          -0.204027
# Real Estate Agent 5 -> Real Estate Agent 3               0.143319
# Real Estate Agent 5 -> Lawyer 3                         -0.139559
# ...                                                           ...
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
# Set Appointment -> View The Property                     0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# View The Property -> Hand In The Paperwork               0.000000
#
#                                                   Importance_Medium  \
# Feature
# yearsOfEducation_Postgraduate Education                    0.149340
# age_Young Adult                                            0.145332
# case:protected                                            -0.022551
# Real Estate Agent 5 -> Real Estate Agent 3                -0.016841
# Real Estate Agent 5 -> Lawyer 3                           -0.017347
# ...                                                             ...
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
# Set Appointment -> View The Property                       0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# View The Property -> Hand In The Paperwork                 0.000000
#
#                                                   Importance_Low
# Feature
# yearsOfEducation_Postgraduate Education                 0.085658
# age_Young Adult                                         0.062744
# case:protected                                         -0.020744
# Real Estate Agent 5 -> Real Estate Agent 3              0.020137
# Real Estate Agent 5 -> Lawyer 3                         0.006109
# ...                                                          ...
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
# Set Appointment -> View The Property                    0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# View The Property -> Hand In The Paperwork              0.000000
#
# [85 rows x 3 columns]

# %% [markdown]
# <b> 2.4 Equalized Odds Postprocessing

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = AIF360.PostEOddsPostprocessingRandomFlorestOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, protected_attribute, alpha = 0.1, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = AIF360.PostEOddsPostprocessingRandomFlorestOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, protected_attribute, alpha = 0.1, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = AIF360.PostEOddsPostprocessingRandomFlorestOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, protected_attribute, alpha = 0.1, num_trials=50)

# %%
#Serão os parâmetros da Random Florest
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'n_estimators': 68, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.9759520666804757}
# Medium - Parâmetros: {'n_estimators': 140, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.838710820158158}
# Low - Parâmetros: {'n_estimators': 90, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.6912235023666262}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Postprocessing: Equalized Odds', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Postprocessing: Equalized Odds', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Postprocessing: Equalized Odds', privileged_group, unprivileged_group)

df_metrics_PostEOdds = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics = pd.concat([df_metrics, df_metrics_PostEOdds], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_post_eodds_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# case:protected                                           0.119353
# age_Young Adult                                          0.052295
# Real Estate Agent 4 -> Real Estate Agent 3              -0.031369
# Lawyer 3 -> Real Estate Agent 4                         -0.029368
# Real Estate Agent 5 -> Lawyer 3                         -0.028444
# ...                                                           ...
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# View The Property -> Hand In The Paperwork               0.000000
# Set Appointment -> View The Property                     0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
#
#                                                   Importance_Medium  \
# Feature
# case:protected                                             0.055502
# age_Young Adult                                           -0.002590
# Real Estate Agent 4 -> Real Estate Agent 3                -0.003897
# Lawyer 3 -> Real Estate Agent 4                           -0.037984
# Real Estate Agent 5 -> Lawyer 3                           -0.002131
# ...                                                             ...
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# View The Property -> Hand In The Paperwork                 0.000000
# Set Appointment -> View The Property                       0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
#
#                                                   Importance_Low
# Feature
# case:protected                                          0.067898
# age_Young Adult                                         0.001364
# Real Estate Agent 4 -> Real Estate Agent 3              0.019702
# Lawyer 3 -> Real Estate Agent 4                         0.009895
# Real Estate Agent 5 -> Lawyer 3                         0.012235
# ...                                                          ...
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# View The Property -> Hand In The Paperwork              0.000000
# Set Appointment -> View The Property                    0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
#
# [85 rows x 3 columns]

# %% [markdown]
# <b> 2.5 Calibrated EqOdds Postprocessing

# %%
# Uso da função:
df_final_high, best_model_high, best_params_high, best_score_high, explanations_high = AIF360.PostCalibratedEOddsRandomFlorestOptuna(X_train_high, y_train_high, X_test_high, y_test_high, df_train_high, df_test_high, protected_attribute, alpha = 0.1, num_trials=50)
df_final_medium, best_model_medium, best_params_medium, best_score_medium, explanations_medium = AIF360.PostCalibratedEOddsRandomFlorestOptuna(X_train_medium, y_train_medium, X_test_medium, y_test_medium, df_train_medium, df_test_medium, protected_attribute, alpha = 0.1, num_trials=50)
df_final_low, best_model_low, best_params_low, best_score_low, explanations_low = AIF360.PostCalibratedEOddsRandomFlorestOptuna(X_train_low, y_train_low, X_test_low, y_test_low, df_train_low, df_test_low, protected_attribute, alpha = 0.1, num_trials=50)
# Out:
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate
# C:\Users\micka\OneDrive\Documentos\[EACH USP] Doutorado\2. Pesquisa\6. Experimento\3. Predictive Process Monitoring\_PythonProcessMining\Metrics.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   di = unprivileged_positive_rate / privileged_positive_rate

# %%
print('High - Parâmetros:', best_params_high)
print('Medium - Parâmetros:', best_params_medium)
print('Low - Parâmetros:', best_params_low)
# Out:
# High - Parâmetros: {'n_estimators': 158, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.7027524061319453, 'cost_constraint': 'fpr'}
# Medium - Parâmetros: {'n_estimators': 153, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.949116166871583, 'cost_constraint': 'fnr'}
# Low - Parâmetros: {'n_estimators': 190, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'class_weight': 'balanced', 'max_samples': 0.6929419911119868, 'cost_constraint': 'fnr'}

# %% [markdown]
# Avaliação do modelo

# %%
#Métricas do modelo
df_metrics_high = Metrics.ModelMetrics(df_final_high, 'case:protected', 'High', 'Postprocessing: Calibrated EqOdds', privileged_group, unprivileged_group)
df_metrics_medium = Metrics.ModelMetrics(df_final_medium, 'case:protected', 'Medium', 'Postprocessing: Calibrated EqOdds', privileged_group, unprivileged_group)
df_metrics_low = Metrics.ModelMetrics(df_final_low, 'case:protected', 'Low', 'Postprocessing: Calibrated EqOdds', privileged_group, unprivileged_group)

df_metrics_PostCalibrated = pd.concat([df_metrics_high, df_metrics_medium, df_metrics_low], ignore_index=True)
df_metrics = pd.concat([df_metrics, df_metrics_PostCalibrated], ignore_index=True)
df_metrics.to_excel(f'{name_prefix}_metrics.xlsx', index = False)
#df_metrics[df_metrics['Metric'].isin(['Accuracy', 'F1-Score', 'Disparate Impact'])]

# %% [markdown]
# Explicação do modelo

# %%
# Gerar tabelas de importância das variáveis
importance_high = get_feature_importance(explanations_high, X_train_high.columns)
importance_medium = get_feature_importance(explanations_medium, X_train_medium.columns)
importance_low = get_feature_importance(explanations_low, X_train_low.columns)

# Criar DataFrames com a importância das variáveis
importance_high_df = pd.DataFrame({'Feature': X_train_high.columns, 'Importance_High': importance_high})
importance_medium_df = pd.DataFrame({'Feature': X_train_medium.columns, 'Importance_Medium': importance_medium})
importance_low_df = pd.DataFrame({'Feature': X_train_low.columns, 'Importance_Low': importance_low})

# Realizar o merge dos DataFrames utilizando 'Feature' como chave e preenchendo valores faltantes com NaN
importance_df = importance_high_df.merge(importance_medium_df, on='Feature', how='outer').merge(importance_low_df, on='Feature', how='outer')

# Ordenar o DataFrame com base no módulo dos valores da coluna 'Importance_High'
importance_df['Importance_High_Abs'] = importance_df['Importance_High'].abs()
importance_df = importance_df.sort_values(by='Importance_High_Abs', ascending=False)
importance_df.drop(columns=['Importance_High_Abs'], inplace=True)

# Definir o índice como a coluna 'Feature'
importance_df.set_index('Feature', inplace=True)

# Salvar o DataFrame como CSV
importance_df.to_csv(f'{name_prefix}_post_calibrated_model_lime.csv')

# Exibir o DataFrame
importance_df
# Out:
#                                                   Importance_High  \
# Feature
# case:protected                                           0.116874
# age_Young Adult                                          0.045951
# Real Estate Agent 5 -> Lawyer 3                         -0.032243
# Real Estate Agent 4 -> Real Estate Agent 4               0.027249
# Lawyer 3 -> Real Estate Agent 4                         -0.024988
# ...                                                           ...
# Check Paperwork -> Screen Prospective Tenant             0.000000
# Apply for Viewing Appointment -> Set Appointment         0.000000
# View The Property -> Hand In The Paperwork               0.000000
# Set Appointment -> View The Property                     0.000000
# Hand In The Paperwork -> Check Paperwork                 0.000000
#
#                                                   Importance_Medium  \
# Feature
# case:protected                                             0.055613
# age_Young Adult                                           -0.005937
# Real Estate Agent 5 -> Lawyer 3                           -0.000734
# Real Estate Agent 4 -> Real Estate Agent 4                -0.044850
# Lawyer 3 -> Real Estate Agent 4                           -0.044437
# ...                                                             ...
# Check Paperwork -> Screen Prospective Tenant               0.000000
# Apply for Viewing Appointment -> Set Appointment           0.000000
# View The Property -> Hand In The Paperwork                 0.000000
# Set Appointment -> View The Property                       0.000000
# Hand In The Paperwork -> Check Paperwork                   0.000000
#
#                                                   Importance_Low
# Feature
# case:protected                                          0.062065
# age_Young Adult                                         0.006766
# Real Estate Agent 5 -> Lawyer 3                         0.009156
# Real Estate Agent 4 -> Real Estate Agent 4             -0.010106
# Lawyer 3 -> Real Estate Agent 4                         0.005133
# ...                                                          ...
# Check Paperwork -> Screen Prospective Tenant            0.000000
# Apply for Viewing Appointment -> Set Appointment        0.000000
# View The Property -> Hand In The Paperwork              0.000000
# Set Appointment -> View The Property                    0.000000
# Hand In The Paperwork -> Check Paperwork                0.000000
#
# [85 rows x 3 columns]
